# %%
import numpy as np
import cv2
from glob import glob
from tqdm import tqdm
import json
import shutil
import os
import pandas as pd
import matplotlib.pyplot as plt
import time
import tensorflow as tf
from tensorflow.keras import backend as K
import tensorflow.keras.backend as K
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, BatchNormalization, ReLU, Concatenate, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.layers import Layer, Input, Conv2D, BatchNormalization, Lambda, Concatenate
print(tf.__version__)
# !pip install git+https://github.com/lucasb-eyer/pydensecrf.git
import pydensecrf.densecrf as dcrf
from pydensecrf.utils import unary_from_softmax, create_pairwise_bilateral
# Out:
# 2025-07-01 03:14:15.438725: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751339655.650651      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751339655.717576      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2.18.0
# Collecting git+https://github.com/lucasb-eyer/pydensecrf.git
#   Cloning https://github.com/lucasb-eyer/pydensecrf.git to /tmp/pip-req-build-ir3fklwz
#   Running command git clone --filter=blob:none --quiet https://github.com/lucasb-eyer/pydensecrf.git /tmp/pip-req-build-ir3fklwz
#   Resolved https://github.com/lucasb-eyer/pydensecrf.git to commit 2723c7fa4f2ead16ae1ce3d8afe977724bb8f87f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: pydensecrf
#   Building wheel for pydensecrf (pyproject.toml) ... done
#   Created wheel for pydensecrf: filename=pydensecrf-1.0-cp311-cp311-linux_x86_64.whl size=3440336 sha256=d94944df1909c5fe9967ee4f68193031c3f7969e4d15c8709ac65d0e504e1b80
#   Stored in directory: /tmp/pip-ephem-wheel-cache-y17scgml/wheels/ce/8e/34/6dcfa200a9e2ae3627d8009b8bd1ca9b24512bec50a93304de
# Successfully built pydensecrf
# Installing collected packages: pydensecrf
# Successfully installed pydensecrf-1.0

# %%
def load_isic_dataset(image_path, mask_path, binary_path, csv_file, img_size=(256, 256)):
    """
    Đọc và xử lý dữ liệu từ ISIC 2017 dataset

    Args:
        image_path: Đường dẫn đến thư mục chứa ảnh gốc
        mask_path: Đường dẫn đến thư mục chứa mask
        binary_path: Đường dẫn đến thư mục chứa mask nhị phân
        csv_file: Đường dẫn đầy đủ đến file CSV chứa nhãn
        label_name: Tên cột chứa nhãn trong file CSV
        img_size: Kích thước ảnh đầu ra (width, height)

    Returns:
        images: Numpy array chứa các ảnh đã xử lý
        masks: Numpy array chứa các mask đã xử lý
        binary_masks: Dict chứa mask nhị phân của từng ảnh đã xử lý
        image_ids: List các ID của ảnh
        labels: List các nhãn tương ứng với ảnh
    """

    # Lấy danh sách các file ảnh
    image_files = sorted(glob(os.path.join(image_path, "ISIC_*.jpg")))

    # Khởi tạo lists để lưu dữ liệu
    images = []
    masks = []
    binary_masks = {}
    image_ids = []
    labels = []

    # Đọc file CSV
    csv_data = pd.read_csv(csv_file)
    mel_label = csv_data['melanoma'].astype("int64")

    print("Đang đọc và xử lý dữ liệu...")
    for index, img_path in enumerate(tqdm(image_files)):
        # Lấy image ID
        img_id = os.path.basename(img_path).split('.')[0]
        mask_file = os.path.join(mask_path, f"{img_id}_segmentation.png")
        binary_file = os.path.join(binary_path, f"{img_id}_features.json")

        # Kiểm tra file mask có tồn tại
        if not os.path.exists(mask_file):
            print(f"Không tìm thấy mask cho ảnh mặt nạ {img_id}_segmentation.png")
            continue
        if not os.path.exists(binary_file):
            print(f"Không tìm thấy mask nhị phân cho ảnh {img_id}_features.json")
            continue

        try:


            # Đọc ảnh gốc
            img = cv2.imread(img_path)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Chuyển từ BGR sang RGB


            # Đọc mask
            mask = cv2.imread(mask_file, cv2.IMREAD_GRAYSCALE)

            # Resize ảnh và mask
            img = cv2.resize(img, img_size)
            mask = cv2.resize(mask, img_size)

            # Normalize
            img = img / 255.0
            mask = mask / 255.0

            # Đọc mask nhị phân
            with open(binary_file, 'r') as f:
                binary_masks[img_id] = json.load(f)

            # Lấy nhãn tương ứng
            label = mel_label[index]

            # Thêm vào lists
            images.append(img)
            masks.append(mask)
            image_ids.append(img_id)
            labels.append(label.astype("long"))

        except Exception as e:
            print(f"Lỗi khi xử lý ảnh {img_id}: {str(e)}")
            continue

    # Chuyển sang numpy arrays
    images = np.array(images)
    masks = np.array(masks)[..., np.newaxis]  # Thêm channel dimension cho masks
    labels = np.array(labels)

    print(f"\nĐã đọc thành công {len(images)} ảnh")
    print(f"Shape của images: {images.shape}")
    print(f"Shape của masks: {masks.shape}")
    print(f"Shape của labels: {labels.shape}")

    return images, masks, binary_masks, image_ids, labels

# %%
# Đọc tập training
train_images, train_masks, train_binarys, train_image_ids, train_labels = load_isic_dataset(
    image_path='/kaggle/input/isic-2750/Train_Data',
    mask_path='/kaggle/input/isic-2750/Train_GroundTruth_1',
    binary_path='/kaggle/input/isic-2750/Train_GroundTruth_2',
    csv_file='/kaggle/input/isic-2750/Train_GroundTruth_3.csv',
    img_size=(256, 256)
)
# Out:
# Đang đọc và xử lý dữ liệu...
# 100%|██████████| 1925/1925 [06:39<00:00,  4.82it/s]
# Đã đọc thành công 1925 ảnh
# Shape của images: (1925, 256, 256, 3)
# Shape của masks: (1925, 256, 256, 1)
# Shape của labels: (1925,)

# %%
test_images, test_masks, test_binarys, test_image_ids, test_labels = load_isic_dataset(
    image_path='/kaggle/input/isic-2750/Test_Data',
    mask_path='/kaggle/input/isic-2750/Test_GroundTruth_1',
    binary_path='/kaggle/input/isic-2750/Test_GroundTruth_2',
    csv_file='/kaggle/input/isic-2750/Test_GroundTruth_3.csv',
     # label_name="melanoma",
    img_size=(256, 256)
)
# Out:
# Đang đọc và xử lý dữ liệu...
# 100%|██████████| 825/825 [02:31<00:00,  5.44it/s]
# Đã đọc thành công 825 ảnh
# Shape của images: (825, 256, 256, 3)
# Shape của masks: (825, 256, 256, 1)
# Shape của labels: (825,)

# %%
def iou_metric(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)

    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection
    iou = (intersection + 1e-7) / (union + 1e-7)
    return iou

# %%
def compute_metric(y_true, y_pred, metric='dice_coefficient', smooth=1e-6, is_numpy=False):
    """Tính Dice hoặc Jaccard coefficient/loss cho TensorFlow hoặc NumPy."""
    y_true_f = y_true.flatten() if is_numpy else K.flatten(y_true)
    y_pred_f = y_pred.flatten() if is_numpy else K.flatten(y_pred)
    intersection = np.sum(y_true_f * y_pred_f) if is_numpy else K.sum(y_true_f * y_pred_f)

    if 'dice' in metric:
        sum_fn = np.sum if is_numpy else K.sum
        score = (2. * intersection + smooth) / (sum_fn(y_true_f) + sum_fn(y_pred_f) + smooth)
    elif 'jaccard' in metric:
        sum_fn = np.sum if is_numpy else K.sum
        union = sum_fn(y_true_f) + sum_fn(y_pred_f) - intersection
        score = (intersection + smooth) / (union + smooth)
    else:
        raise ValueError(f"Unsupported metric: {metric}")

    return score if 'coefficient' in metric else 1 - score

# Hàm TensorFlow
def dice_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_coefficient', smooth)

def dice_loss(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_loss', smooth)

def jaccard_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'jaccard_coefficient', smooth)

def jaccard_loss(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'jaccard_loss', smooth)

# Hàm NumPy
def np_accuracy(y_true, y_pred):
    return np.mean(y_true.flatten() == y_pred.flatten())

def np_dice_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_coefficient', smooth, is_numpy=True)

def np_jaccard_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'jaccard_coefficient', smooth, is_numpy=True)

def np_dice_loss(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_loss', smooth, is_numpy=True)

# %%
def CustomSegUNet(input_size=(256, 256, 1)):
    inputs = Input(input_size)

    # Encoder
    c1 = Conv2D(64, (3, 3), padding='same')(inputs)
    c1 = BatchNormalization()(c1)
    c1 = tf.keras.layers.ReLU()(c1)
    c1 = Conv2D(64, (3, 3), padding='same')(c1)
    c1 = BatchNormalization()(c1)
    c1 = tf.keras.layers.ReLU()(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = Conv2D(128, (3, 3), padding='same')(p1)
    c2 = BatchNormalization()(c2)
    c2 = tf.keras.layers.ReLU()(c2)
    c2 = Conv2D(128, (3, 3), padding='same')(c2)
    c2 = BatchNormalization()(c2)
    c2 = tf.keras.layers.ReLU()(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = Conv2D(256, (3, 3), padding='same')(p2)
    c3 = BatchNormalization()(c3)
    c3 = tf.keras.layers.ReLU()(c3)
    c3 = Conv2D(256, (3, 3), padding='same')(c3)
    c3 = BatchNormalization()(c3)
    c3 = tf.keras.layers.ReLU()(c3)
    c3 = Conv2D(256, (3, 3), padding='same')(c3)
    c3 = BatchNormalization()(c3)
    c3 = tf.keras.layers.ReLU()(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    c4 = Conv2D(512, (3, 3), padding='same')(p3)
    c4 = BatchNormalization()(c4)
    c4 = tf.keras.layers.ReLU()(c4)
    c4 = Conv2D(512, (3, 3), padding='same')(c4)
    c4 = BatchNormalization()(c4)
    c4 = tf.keras.layers.ReLU()(c4)
    c4 = Conv2D(512, (3, 3), padding='same')(c4)
    c4 = BatchNormalization()(c4)
    c4 = tf.keras.layers.ReLU()(c4)
    p4 = MaxPooling2D((2, 2))(c4)

    c5 = Conv2D(512, (3, 3), padding='same')(p4)
    c5 = BatchNormalization()(c5)
    c5 = tf.keras.layers.ReLU()(c5)
    c5 = Conv2D(512, (3, 3), padding='same')(c5)
    c5 = BatchNormalization()(c5)
    c5 = tf.keras.layers.ReLU()(c5)
    c5 = Conv2D(512, (3, 3), padding='same')(c5)
    c5 = BatchNormalization()(c5)
    c5 = tf.keras.layers.ReLU()(c5)
    p5 = MaxPooling2D((2, 2))(c5)

    # bottleneck
    c6 = Conv2D(1024, (3, 3), padding='same')(p5)
    c6 = BatchNormalization()(c6)
    c6 = tf.keras.layers.ReLU()(c6)
    c6 = Conv2D(1024, (3, 3), padding='same')(c6)
    c6 = BatchNormalization()(c6)
    c6 = tf.keras.layers.ReLU()(c6)
    c6 = Conv2D(1024, (3, 3), padding='same')(c6)
    c6 = BatchNormalization()(c6)
    c6 = tf.keras.layers.ReLU()(c6)

    # Decoder
    u7 = UpSampling2D((2, 2))(c6)
    u7 = Concatenate()([u7, c5])
    c7 = Conv2D(512, (3, 3), padding='same')(u7)
    c7 = BatchNormalization()(c7)
    c7 = tf.keras.layers.ReLU()(c7)
    c7 = Conv2D(512, (3, 3), padding='same')(c7)
    c7 = BatchNormalization()(c7)
    c7 = tf.keras.layers.ReLU()(c7)
    c7 = Conv2D(512, (3, 3), padding='same')(c7)
    c7 = BatchNormalization()(c7)
    c7 = tf.keras.layers.ReLU()(c7)

    u8 = UpSampling2D((2, 2))(c7)
    u8 = Concatenate()([u8, c4])
    c8 = Conv2D(512, (3, 3), padding='same')(u8)
    c8 = BatchNormalization()(c8)
    c8 = tf.keras.layers.ReLU()(c8)
    c8 = Conv2D(512, (3, 3), padding='same')(c8)
    c8 = BatchNormalization()(c8)
    c8 = tf.keras.layers.ReLU()(c8)
    c8 = Conv2D(256, (3, 3), padding='same')(c8)
    c8 = BatchNormalization()(c8)
    c8 = tf.keras.layers.ReLU()(c8)

    u9 = UpSampling2D((2, 2))(c8)
    u9 = Concatenate()([u9, c3])
    c9 = Conv2D(256, (3, 3), padding='same')(u9)
    c9 = BatchNormalization()(c9)
    c9 = tf.keras.layers.ReLU()(c9)
    c9 = Conv2D(256, (3, 3), padding='same')(c9)
    c9 = BatchNormalization()(c9)
    c9 = tf.keras.layers.ReLU()(c9)
    c9 = Conv2D(128, (3, 3), padding='same')(c9)
    c9 = BatchNormalization()(c9)
    c9 = tf.keras.layers.ReLU()(c9)

    u10 = UpSampling2D((2, 2))(c9)
    u10 = Concatenate()([u10, c2])
    c10 = Conv2D(128, (3, 3), padding='same')(u10)
    c10 = BatchNormalization()(c10)
    c10 = tf.keras.layers.ReLU()(c10)
    c10 = Conv2D(64, (3, 3), padding='same')(c10)
    c10 = BatchNormalization()(c10)
    c10 = tf.keras.layers.ReLU()(c10)

    u11 = UpSampling2D((2, 2))(c10)
    u11 = Concatenate()([u11, c1])
    c11 = Conv2D(64, (3, 3), padding='same')(u11)
    c11 = BatchNormalization()(c11)
    c11 = tf.keras.layers.ReLU()(c11)

    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c11)

    return Model(inputs=inputs, outputs=outputs)

# Khởi tạo và kiểm tra mô hình
if __name__ == "__main__":
    model = CustomSegUNet()
    model.summary()
# Out:
# I0000 00:00:1751340269.148213      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 256, 256, 1)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 256, 256, 64)   │            640 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 256, 256, 64)   │            256 │ conv2d[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu (ReLU)              │ (None, 256, 256, 64)   │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 256, 256, 64)   │         36,928 │ re_lu[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 256, 256, 64)   │            256 │ conv2d_1[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1 (ReLU)            │ (None, 256, 256, 64)   │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 128, 128, 64)   │              0 │ re_lu_1[0][0]          │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 128, 128, 128)  │         73,856 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 128, 128, 128)  │            512 │ conv2d_2[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_2 (ReLU)            │ (None, 128, 128, 128)  │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 128, 128, 128)  │        147,584 │ re_lu_2[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 128, 128, 128)  │            512 │ conv2d_3[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_3 (ReLU)            │ (None, 128, 128, 128)  │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 64, 64, 128)    │              0 │ re_lu_3[0][0]          │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 64, 64, 256)    │        295,168 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 64, 64, 256)    │          1,024 │ conv2d_4[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_4 (ReLU)            │ (None, 64, 64, 256)    │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 64, 64, 256)    │        590,080 │ re_lu_4[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_5     │ (None, 64, 64, 256)    │          1,024 │ conv2d_5[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_5 (ReLU)            │ (None, 64, 64, 256)    │              0 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 64, 64, 256)    │        590,080 │ re_lu_5[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_6     │ (None, 64, 64, 256)    │          1,024 │ conv2d_6[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_6 (ReLU)            │ (None, 64, 64, 256)    │              0 │ batch_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 32, 32, 256)    │              0 │ re_lu_6[0][0]          │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 32, 32, 512)    │      1,180,160 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_7     │ (None, 32, 32, 512)    │          2,048 │ conv2d_7[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_7 (ReLU)            │ (None, 32, 32, 512)    │              0 │ batch_normalization_7… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 32, 32, 512)    │      2,359,808 │ re_lu_7[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_8     │ (None, 32, 32, 512)    │          2,048 │ conv2d_8[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_8 (ReLU)            │ (None, 32, 32, 512)    │              0 │ batch_normalization_8… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 32, 32, 512)    │      2,359,808 │ re_lu_8[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_9     │ (None, 32, 32, 512)    │          2,048 │ conv2d_9[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_9 (ReLU)            │ (None, 32, 32, 512)    │              0 │ batch_normalization_9… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_3           │ (None, 16, 16, 512)    │              0 │ re_lu_9[0][0]          │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_10 (Conv2D)        │ (None, 16, 16, 512)    │      2,359,808 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_10    │ (None, 16, 16, 512)    │          2,048 │ conv2d_10[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_10 (ReLU)           │ (None, 16, 16, 512)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_11 (Conv2D)        │ (None, 16, 16, 512)    │      2,359,808 │ re_lu_10[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_11    │ (None, 16, 16, 512)    │          2,048 │ conv2d_11[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_11 (ReLU)           │ (None, 16, 16, 512)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_12 (Conv2D)        │ (None, 16, 16, 512)    │      2,359,808 │ re_lu_11[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_12    │ (None, 16, 16, 512)    │          2,048 │ conv2d_12[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_12 (ReLU)           │ (None, 16, 16, 512)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_4           │ (None, 8, 8, 512)      │              0 │ re_lu_12[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_13 (Conv2D)        │ (None, 8, 8, 1024)     │      4,719,616 │ max_pooling2d_4[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_13    │ (None, 8, 8, 1024)     │          4,096 │ conv2d_13[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_13 (ReLU)           │ (None, 8, 8, 1024)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_14 (Conv2D)        │ (None, 8, 8, 1024)     │      9,438,208 │ re_lu_13[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_14    │ (None, 8, 8, 1024)     │          4,096 │ conv2d_14[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_14 (ReLU)           │ (None, 8, 8, 1024)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_15 (Conv2D)        │ (None, 8, 8, 1024)     │      9,438,208 │ re_lu_14[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_15    │ (None, 8, 8, 1024)     │          4,096 │ conv2d_15[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_15 (ReLU)           │ (None, 8, 8, 1024)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d             │ (None, 16, 16, 1024)   │              0 │ re_lu_15[0][0]         │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 16, 16, 1536)   │              0 │ up_sampling2d[0][0],   │
# │                           │                        │                │ re_lu_12[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_16 (Conv2D)        │ (None, 16, 16, 512)    │      7,078,400 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_16    │ (None, 16, 16, 512)    │          2,048 │ conv2d_16[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_16 (ReLU)           │ (None, 16, 16, 512)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_17 (Conv2D)        │ (None, 16, 16, 512)    │      2,359,808 │ re_lu_16[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_17    │ (None, 16, 16, 512)    │          2,048 │ conv2d_17[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_17 (ReLU)           │ (None, 16, 16, 512)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_18 (Conv2D)        │ (None, 16, 16, 512)    │      2,359,808 │ re_lu_17[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_18    │ (None, 16, 16, 512)    │          2,048 │ conv2d_18[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_18 (ReLU)           │ (None, 16, 16, 512)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_1           │ (None, 32, 32, 512)    │              0 │ re_lu_18[0][0]         │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 32, 32, 1024)   │              0 │ up_sampling2d_1[0][0], │
# │ (Concatenate)             │                        │                │ re_lu_9[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_19 (Conv2D)        │ (None, 32, 32, 512)    │      4,719,104 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_19    │ (None, 32, 32, 512)    │          2,048 │ conv2d_19[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_19 (ReLU)           │ (None, 32, 32, 512)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_20 (Conv2D)        │ (None, 32, 32, 512)    │      2,359,808 │ re_lu_19[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_20    │ (None, 32, 32, 512)    │          2,048 │ conv2d_20[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_20 (ReLU)           │ (None, 32, 32, 512)    │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_21 (Conv2D)        │ (None, 32, 32, 256)    │      1,179,904 │ re_lu_20[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_21    │ (None, 32, 32, 256)    │          1,024 │ conv2d_21[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_21 (ReLU)           │ (None, 32, 32, 256)    │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_2           │ (None, 64, 64, 256)    │              0 │ re_lu_21[0][0]         │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 64, 64, 512)    │              0 │ up_sampling2d_2[0][0], │
# │ (Concatenate)             │                        │                │ re_lu_6[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_22 (Conv2D)        │ (None, 64, 64, 256)    │      1,179,904 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_22    │ (None, 64, 64, 256)    │          1,024 │ conv2d_22[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_22 (ReLU)           │ (None, 64, 64, 256)    │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_23 (Conv2D)        │ (None, 64, 64, 256)    │        590,080 │ re_lu_22[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_23    │ (None, 64, 64, 256)    │          1,024 │ conv2d_23[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_23 (ReLU)           │ (None, 64, 64, 256)    │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_24 (Conv2D)        │ (None, 64, 64, 128)    │        295,040 │ re_lu_23[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_24    │ (None, 64, 64, 128)    │            512 │ conv2d_24[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_24 (ReLU)           │ (None, 64, 64, 128)    │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_3           │ (None, 128, 128, 128)  │              0 │ re_lu_24[0][0]         │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_3             │ (None, 128, 128, 256)  │              0 │ up_sampling2d_3[0][0], │
# │ (Concatenate)             │                        │                │ re_lu_3[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_25 (Conv2D)        │ (None, 128, 128, 128)  │        295,040 │ concatenate_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_25    │ (None, 128, 128, 128)  │            512 │ conv2d_25[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_25 (ReLU)           │ (None, 128, 128, 128)  │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_26 (Conv2D)        │ (None, 128, 128, 64)   │         73,792 │ re_lu_25[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_26    │ (None, 128, 128, 64)   │            256 │ conv2d_26[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_26 (ReLU)           │ (None, 128, 128, 64)   │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_4           │ (None, 256, 256, 64)   │              0 │ re_lu_26[0][0]         │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_4             │ (None, 256, 256, 128)  │              0 │ up_sampling2d_4[0][0], │
# │ (Concatenate)             │                        │                │ re_lu_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_27 (Conv2D)        │ (None, 256, 256, 64)   │         73,792 │ concatenate_4[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_27    │ (None, 256, 256, 64)   │            256 │ conv2d_27[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_27 (ReLU)           │ (None, 256, 256, 64)   │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_28 (Conv2D)        │ (None, 256, 256, 1)    │             65 │ re_lu_27[0][0]         │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 60,918,145 (232.38 MB)
#  Trainable params: 60,896,129 (232.30 MB)
#  Non-trainable params: 22,016 (86.00 KB)

# %%
class EarlyStoppingByAccuracyChange(tf.keras.callbacks.Callback):
    def __init__(self, monitor='accuracy', threshold=0.00001, patience=3, verbose=0):
        super(EarlyStoppingByAccuracyChange, self).__init__()
        self.monitor = monitor
        self.threshold = threshold
        self.patience = patience
        self.verbose = verbose
        self.wait = 0
        self.best_accuracy = -float('inf')
        self.consecutive_stops = 0

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        current_accuracy = logs.get(self.monitor)
        if current_accuracy is None:
            tf.get_logger().warning(
                'Early stopping requires %s available!', self.monitor
            )
            return

        if current_accuracy > self.best_accuracy:
            self.best_accuracy = current_accuracy
            self.wait = 0
            self.consecutive_stops = 0
        else:
            self.wait += 1
            accuracy_change = current_accuracy - self.best_accuracy
            if abs(accuracy_change) < self.threshold:
                self.consecutive_stops += 1
                if self.consecutive_stops >= self.patience:
                    if self.verbose > 0:
                        print(f"Epoch {epoch+1}: Early stopping triggered due to minimal accuracy change for {self.patience} epochs.")
                    self.model.stop_training = True
            else:
                self.consecutive_stops = 0

# %%
def convert_to_gray_clahe(images):
    grays = []
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))  # tạo đối tượng CLAHE

    for img in images:
        if img.dtype != np.uint8:
            img = (img * 255).astype(np.uint8)
        gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)  # chuyển sang ảnh xám

        img_clahe = clahe.apply(gray)  # áp dụng CLAHE
        grays.append(img_clahe)


    return np.array(grays)

# Gọi hàm
train_images_gray_clahe = convert_to_gray_clahe(train_images)
test_images_gray_clahe = convert_to_gray_clahe(test_images)

# %%
print("Train images shape:", train_images_gray_clahe.shape)
print("Train masks shape:", train_masks.shape)
# Out:
# Train images shape: (1925, 256, 256)
# Train masks shape: (1925, 256, 256, 1)

# %%
import time

initial_lr = 0.001
# lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
#     initial_lr, decay_steps=100000, decay_rate=0.96, staircase=True)

optimizer = Adam(learning_rate=initial_lr)


segunet = CustomSegUNet(input_size=(256, 256, 1))
segunet.compile(
    optimizer=optimizer,
    loss=dice_loss,
    metrics=['accuracy', jaccard_coefficient]
)

# Thiết lập thư mục lưu mô hình
model_checkpoint_dir = 'model'
# os.makedirs(model_checkpoint_dir, exist_ok=True)

checkpoint_path = os.path.join(model_checkpoint_dir, 'cp.ckpt')

checkpoint_callback = ModelCheckpoint(
    filepath=os.path.join(model_checkpoint_dir, 'begin.weights.h5'),
    save_weights_only=True,
    monitor='loss',
    mode='min',
    save_best_only=True,
    verbose=1
)

# Callback theo dõi train accuracy thay vì validation loss/accuracy
early_stopping = EarlyStoppingByAccuracyChange(
    monitor='accuracy',
    threshold=0.00001,
    patience=10,
    verbose=1
)
# ReduceLROnPlateau Callback
lr_reduction = ReduceLROnPlateau(monitor='loss',
                                  patience=5,
                                  verbose=1,
                                  factor=0.5,
                                  min_lr=0.00001)


# --- Tính thời gian huấn luyện ---
start_time = time.time()

# Huấn luyện mô hình
history = segunet.fit(
    train_images_gray_clahe, train_masks,
    batch_size=32,
    epochs=100,
    callbacks=[early_stopping, lr_reduction, checkpoint_callback]
)

end_time = time.time()
training_time = end_time - start_time

# --- Tính trung bình Accuracy và Jaccard ---
avg_accuracy = np.mean(history.history['accuracy'])
avg_jaccard = np.mean(history.history['jaccard_coefficient'])

# --- In kết quả ---
print("SegUNet output shape:", segunet.output_shape)
print(f"⏱️ Thời gian huấn luyện: {training_time:.2f} giây")
print(f"✅ Accuracy trung bình: {avg_accuracy*100:.2f}%")
print(f"🔗 Jaccard trung bình: {avg_jaccard*100:.2f}%")
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1751340301.895876     177 service.cc:148] XLA service 0x7c550c01e660 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1751340301.897298     177 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1751340304.400420     177 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-07-01 03:25:32.944428: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng2{k2=3,k3=0} for conv (f32[32,128,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,64,256,256]{3,2,1,0}, f32[64,128,3,3]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-07-01 03:25:32.947003: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.002808467s
# Trying algorithm eng2{k2=3,k3=0} for conv (f32[32,128,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,64,256,256]{3,2,1,0}, f32[64,128,3,3]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# I0000 00:00:1751340374.097494     177 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 714ms/step - accuracy: 0.8123 - jaccard_coefficient: 0.4396 - loss: 0.3991
# E0000 00:00:1751340420.821895     177 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1751340421.056242     177 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1751340421.620593     177 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1751340421.878212     177 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1751340424.627470     177 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1751340424.862214     177 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8132 - jaccard_coefficient: 0.4406 - loss: 0.3980
# Epoch 1: loss improved from inf to 0.33592, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 168s 1s/step - accuracy: 0.8140 - jaccard_coefficient: 0.4416 - loss: 0.3970 - learning_rate: 0.0010
# Epoch 2/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 706ms/step - accuracy: 0.9041 - jaccard_coefficient: 0.5990 - loss: 0.2531
# Epoch 2: loss improved from 0.33592 to 0.24155, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 742ms/step - accuracy: 0.9041 - jaccard_coefficient: 0.5992 - loss: 0.2529 - learning_rate: 0.0010
# Epoch 3/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 707ms/step - accuracy: 0.9132 - jaccard_coefficient: 0.6278 - loss: 0.2301
# Epoch 3: loss improved from 0.24155 to 0.21867, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 742ms/step - accuracy: 0.9132 - jaccard_coefficient: 0.6280 - loss: 0.2299 - learning_rate: 0.0010
# Epoch 4/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 706ms/step - accuracy: 0.9200 - jaccard_coefficient: 0.6666 - loss: 0.2012
# Epoch 4: loss improved from 0.21867 to 0.19032, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 742ms/step - accuracy: 0.9201 - jaccard_coefficient: 0.6668 - loss: 0.2011 - learning_rate: 0.0010
# Epoch 5/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 706ms/step - accuracy: 0.9285 - jaccard_coefficient: 0.6961 - loss: 0.1806
# Epoch 5: loss improved from 0.19032 to 0.17765, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 742ms/step - accuracy: 0.9285 - jaccard_coefficient: 0.6962 - loss: 0.1805 - learning_rate: 0.0010
# Epoch 6/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 707ms/step - accuracy: 0.9346 - jaccard_coefficient: 0.7178 - loss: 0.1651
# Epoch 6: loss improved from 0.17765 to 0.16369, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 742ms/step - accuracy: 0.9347 - jaccard_coefficient: 0.7177 - loss: 0.1651 - learning_rate: 0.0010
# Epoch 7/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 706ms/step - accuracy: 0.9386 - jaccard_coefficient: 0.7288 - loss: 0.1577
# Epoch 7: loss improved from 0.16369 to 0.16020, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 742ms/step - accuracy: 0.9386 - jaccard_coefficient: 0.7287 - loss: 0.1577 - learning_rate: 0.0010
# Epoch 8/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 707ms/step - accuracy: 0.9394 - jaccard_coefficient: 0.7306 - loss: 0.1564
# Epoch 8: loss improved from 0.16020 to 0.15413, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 742ms/step - accuracy: 0.9394 - jaccard_coefficient: 0.7306 - loss: 0.1564 - learning_rate: 0.0010
# Epoch 9/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 707ms/step - accuracy: 0.9427 - jaccard_coefficient: 0.7487 - loss: 0.1447
# Epoch 9: loss improved from 0.15413 to 0.14786, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 742ms/step - accuracy: 0.9427 - jaccard_coefficient: 0.7486 - loss: 0.1447 - learning_rate: 0.0010
# Epoch 10/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 707ms/step - accuracy: 0.9438 - jaccard_coefficient: 0.7484 - loss: 0.1448
# Epoch 10: loss improved from 0.14786 to 0.14398, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 742ms/step - accuracy: 0.9438 - jaccard_coefficient: 0.7485 - loss: 0.1447 - learning_rate: 0.0010
# Epoch 11/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 707ms/step - accuracy: 0.9375 - jaccard_coefficient: 0.7432 - loss: 0.1479
# Epoch 11: loss improved from 0.14398 to 0.13981, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 743ms/step - accuracy: 0.9376 - jaccard_coefficient: 0.7434 - loss: 0.1478 - learning_rate: 0.0010
# Epoch 12/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 707ms/step - accuracy: 0.9453 - jaccard_coefficient: 0.7621 - loss: 0.1357
# Epoch 12: loss improved from 0.13981 to 0.13742, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 743ms/step - accuracy: 0.9453 - jaccard_coefficient: 0.7620 - loss: 0.1358 - learning_rate: 0.0010
# Epoch 13/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 707ms/step - accuracy: 0.9359 - jaccard_coefficient: 0.7221 - loss: 0.1624
# Epoch 13: loss did not improve from 0.13742
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 707ms/step - accuracy: 0.9360 - jaccard_coefficient: 0.7224 - loss: 0.1623 - learning_rate: 0.0010
# Epoch 14/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 707ms/step - accuracy: 0.9459 - jaccard_coefficient: 0.7693 - loss: 0.1313
# Epoch 14: loss improved from 0.13742 to 0.13384, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 744ms/step - accuracy: 0.9460 - jaccard_coefficient: 0.7692 - loss: 0.1314 - learning_rate: 0.0010
# Epoch 15/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 707ms/step - accuracy: 0.9481 - jaccard_coefficient: 0.7613 - loss: 0.1365
# Epoch 15: loss improved from 0.13384 to 0.13073, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 742ms/step - accuracy: 0.9481 - jaccard_coefficient: 0.7615 - loss: 0.1365 - learning_rate: 0.0010
# Epoch 16/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 707ms/step - accuracy: 0.9470 - jaccard_coefficient: 0.7737 - loss: 0.1282
# Epoch 16: loss did not improve from 0.13073
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 707ms/step - accuracy: 0.9470 - jaccard_coefficient: 0.7736 - loss: 0.1282 - learning_rate: 0.0010
# Epoch 17/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 707ms/step - accuracy: 0.9493 - jaccard_coefficient: 0.7787 - loss: 0.1250
# Epoch 17: loss improved from 0.13073 to 0.13036, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 743ms/step - accuracy: 0.9492 - jaccard_coefficient: 0.7785 - loss: 0.1251 - learning_rate: 0.0010
# Epoch 18/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 707ms/step - accuracy: 0.9465 - jaccard_coefficient: 0.7713 - loss: 0.1296
# Epoch 18: loss improved from 0.13036 to 0.12896, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 743ms/step - accuracy: 0.9465 - jaccard_coefficient: 0.7713 - loss: 0.1296 - learning_rate: 0.0010
# Epoch 19/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9502 - jaccard_coefficient: 0.7759 - loss: 0.1268
# Epoch 19: loss improved from 0.12896 to 0.12650, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 743ms/step - accuracy: 0.9502 - jaccard_coefficient: 0.7759 - loss: 0.1268 - learning_rate: 0.0010
# Epoch 20/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 707ms/step - accuracy: 0.9513 - jaccard_coefficient: 0.7788 - loss: 0.1254
# Epoch 20: loss improved from 0.12650 to 0.12122, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 743ms/step - accuracy: 0.9513 - jaccard_coefficient: 0.7789 - loss: 0.1254 - learning_rate: 0.0010
# Epoch 21/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 707ms/step - accuracy: 0.9532 - jaccard_coefficient: 0.7916 - loss: 0.1167
# Epoch 21: loss improved from 0.12122 to 0.12023, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 744ms/step - accuracy: 0.9532 - jaccard_coefficient: 0.7915 - loss: 0.1168 - learning_rate: 0.0010
# Epoch 22/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 707ms/step - accuracy: 0.9504 - jaccard_coefficient: 0.7783 - loss: 0.1253
# Epoch 22: loss did not improve from 0.12023
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9504 - jaccard_coefficient: 0.7783 - loss: 0.1253 - learning_rate: 0.0010
# Epoch 23/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9488 - jaccard_coefficient: 0.7748 - loss: 0.1276
# Epoch 23: loss did not improve from 0.12023
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9488 - jaccard_coefficient: 0.7748 - loss: 0.1276 - learning_rate: 0.0010
# Epoch 24/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 707ms/step - accuracy: 0.9553 - jaccard_coefficient: 0.7962 - loss: 0.1140
# Epoch 24: loss improved from 0.12023 to 0.11517, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 745ms/step - accuracy: 0.9553 - jaccard_coefficient: 0.7962 - loss: 0.1141 - learning_rate: 0.0010
# Epoch 25/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 707ms/step - accuracy: 0.9564 - jaccard_coefficient: 0.8049 - loss: 0.1086
# Epoch 25: loss improved from 0.11517 to 0.11083, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 744ms/step - accuracy: 0.9564 - jaccard_coefficient: 0.8049 - loss: 0.1087 - learning_rate: 0.0010
# Epoch 26/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 707ms/step - accuracy: 0.9555 - jaccard_coefficient: 0.7971 - loss: 0.1136
# Epoch 26: loss improved from 0.11083 to 0.10995, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 743ms/step - accuracy: 0.9555 - jaccard_coefficient: 0.7972 - loss: 0.1136 - learning_rate: 0.0010
# Epoch 27/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9557 - jaccard_coefficient: 0.8035 - loss: 0.1093
# Epoch 27: loss did not improve from 0.10995
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9557 - jaccard_coefficient: 0.8035 - loss: 0.1093 - learning_rate: 0.0010
# Epoch 28/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 707ms/step - accuracy: 0.9572 - jaccard_coefficient: 0.8076 - loss: 0.1068
# Epoch 28: loss improved from 0.10995 to 0.10633, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 744ms/step - accuracy: 0.9572 - jaccard_coefficient: 0.8077 - loss: 0.1068 - learning_rate: 0.0010
# Epoch 29/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9562 - jaccard_coefficient: 0.8014 - loss: 0.1107
# Epoch 29: loss did not improve from 0.10633
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9561 - jaccard_coefficient: 0.8015 - loss: 0.1107 - learning_rate: 0.0010
# Epoch 30/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 707ms/step - accuracy: 0.9561 - jaccard_coefficient: 0.8102 - loss: 0.1053
# Epoch 30: loss did not improve from 0.10633
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9561 - jaccard_coefficient: 0.8101 - loss: 0.1054 - learning_rate: 0.0010
# Epoch 31/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 707ms/step - accuracy: 0.9547 - jaccard_coefficient: 0.7992 - loss: 0.1122
# Epoch 31: loss did not improve from 0.10633
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9547 - jaccard_coefficient: 0.7992 - loss: 0.1122 - learning_rate: 0.0010
# Epoch 32/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9581 - jaccard_coefficient: 0.8054 - loss: 0.1082
# Epoch 32: loss did not improve from 0.10633
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9581 - jaccard_coefficient: 0.8054 - loss: 0.1082 - learning_rate: 0.0010
# Epoch 33/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 707ms/step - accuracy: 0.9570 - jaccard_coefficient: 0.8111 - loss: 0.1047
# Epoch 33: loss improved from 0.10633 to 0.10209, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 743ms/step - accuracy: 0.9571 - jaccard_coefficient: 0.8112 - loss: 0.1046 - learning_rate: 0.0010
# Epoch 34/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 707ms/step - accuracy: 0.9581 - jaccard_coefficient: 0.8146 - loss: 0.1026
# Epoch 34: loss did not improve from 0.10209
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9581 - jaccard_coefficient: 0.8146 - loss: 0.1026 - learning_rate: 0.0010
# Epoch 35/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9616 - jaccard_coefficient: 0.8256 - loss: 0.0958
# Epoch 35: loss improved from 0.10209 to 0.09788, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 744ms/step - accuracy: 0.9616 - jaccard_coefficient: 0.8256 - loss: 0.0958 - learning_rate: 0.0010
# Epoch 36/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 707ms/step - accuracy: 0.9621 - jaccard_coefficient: 0.8285 - loss: 0.0940
# Epoch 36: loss improved from 0.09788 to 0.09557, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 744ms/step - accuracy: 0.9621 - jaccard_coefficient: 0.8285 - loss: 0.0941 - learning_rate: 0.0010
# Epoch 37/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9600 - jaccard_coefficient: 0.8213 - loss: 0.0986
# Epoch 37: loss did not improve from 0.09557
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9600 - jaccard_coefficient: 0.8213 - loss: 0.0986 - learning_rate: 0.0010
# Epoch 38/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9601 - jaccard_coefficient: 0.8179 - loss: 0.1005
# Epoch 38: loss did not improve from 0.09557
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9601 - jaccard_coefficient: 0.8180 - loss: 0.1005 - learning_rate: 0.0010
# Epoch 39/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9611 - jaccard_coefficient: 0.8231 - loss: 0.0975
# Epoch 39: loss improved from 0.09557 to 0.09494, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 742ms/step - accuracy: 0.9611 - jaccard_coefficient: 0.8231 - loss: 0.0975 - learning_rate: 0.0010
# Epoch 40/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9645 - jaccard_coefficient: 0.8363 - loss: 0.0895
# Epoch 40: loss improved from 0.09494 to 0.09423, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 742ms/step - accuracy: 0.9645 - jaccard_coefficient: 0.8362 - loss: 0.0895 - learning_rate: 0.0010
# Epoch 41/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9623 - jaccard_coefficient: 0.8245 - loss: 0.0965
# Epoch 41: loss improved from 0.09423 to 0.09371, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 743ms/step - accuracy: 0.9623 - jaccard_coefficient: 0.8246 - loss: 0.0965 - learning_rate: 0.0010
# Epoch 42/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9657 - jaccard_coefficient: 0.8406 - loss: 0.0869
# Epoch 42: loss improved from 0.09371 to 0.08684, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 739ms/step - accuracy: 0.9657 - jaccard_coefficient: 0.8406 - loss: 0.0869 - learning_rate: 0.0010
# Epoch 43/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9676 - jaccard_coefficient: 0.8500 - loss: 0.0814
# Epoch 43: loss improved from 0.08684 to 0.08592, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 742ms/step - accuracy: 0.9676 - jaccard_coefficient: 0.8498 - loss: 0.0814 - learning_rate: 0.0010
# Epoch 44/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9658 - jaccard_coefficient: 0.8431 - loss: 0.0853
# Epoch 44: loss improved from 0.08592 to 0.08499, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 739ms/step - accuracy: 0.9658 - jaccard_coefficient: 0.8431 - loss: 0.0853 - learning_rate: 0.0010
# Epoch 45/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9666 - jaccard_coefficient: 0.8477 - loss: 0.0826
# Epoch 45: loss improved from 0.08499 to 0.08368, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9666 - jaccard_coefficient: 0.8476 - loss: 0.0827 - learning_rate: 0.0010
# Epoch 46/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9627 - jaccard_coefficient: 0.8249 - loss: 0.0962
# Epoch 46: loss did not improve from 0.08368
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9626 - jaccard_coefficient: 0.8249 - loss: 0.0962 - learning_rate: 0.0010
# Epoch 47/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9644 - jaccard_coefficient: 0.8347 - loss: 0.0904
# Epoch 47: loss did not improve from 0.08368
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9644 - jaccard_coefficient: 0.8347 - loss: 0.0904 - learning_rate: 0.0010
# Epoch 48/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9652 - jaccard_coefficient: 0.8402 - loss: 0.0871
# Epoch 48: loss did not improve from 0.08368
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9652 - jaccard_coefficient: 0.8402 - loss: 0.0870 - learning_rate: 0.0010
# Epoch 49/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9672 - jaccard_coefficient: 0.8514 - loss: 0.0807
# Epoch 49: loss improved from 0.08368 to 0.08101, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 742ms/step - accuracy: 0.9672 - jaccard_coefficient: 0.8514 - loss: 0.0807 - learning_rate: 0.0010
# Epoch 50/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9693 - jaccard_coefficient: 0.8529 - loss: 0.0797
# Epoch 50: loss improved from 0.08101 to 0.07952, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 743ms/step - accuracy: 0.9693 - jaccard_coefficient: 0.8529 - loss: 0.0796 - learning_rate: 0.0010
# Epoch 51/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9680 - jaccard_coefficient: 0.8521 - loss: 0.0800
# Epoch 51: loss did not improve from 0.07952
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9680 - jaccard_coefficient: 0.8520 - loss: 0.0801 - learning_rate: 0.0010
# Epoch 52/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9612 - jaccard_coefficient: 0.8244 - loss: 0.0969
# Epoch 52: loss did not improve from 0.07952
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9612 - jaccard_coefficient: 0.8244 - loss: 0.0969 - learning_rate: 0.0010
# Epoch 53/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9641 - jaccard_coefficient: 0.8391 - loss: 0.0878
# Epoch 53: loss did not improve from 0.07952
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9642 - jaccard_coefficient: 0.8391 - loss: 0.0877 - learning_rate: 0.0010
# Epoch 54/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9673 - jaccard_coefficient: 0.8479 - loss: 0.0826
# Epoch 54: loss did not improve from 0.07952
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9673 - jaccard_coefficient: 0.8479 - loss: 0.0826 - learning_rate: 0.0010
# Epoch 55/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9680 - jaccard_coefficient: 0.8505 - loss: 0.0811
# Epoch 55: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 55: loss improved from 0.07952 to 0.07948, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 743ms/step - accuracy: 0.9680 - jaccard_coefficient: 0.8506 - loss: 0.0810 - learning_rate: 0.0010
# Epoch 56/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 709ms/step - accuracy: 0.9694 - jaccard_coefficient: 0.8591 - loss: 0.0760
# Epoch 56: loss improved from 0.07948 to 0.07476, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 743ms/step - accuracy: 0.9694 - jaccard_coefficient: 0.8591 - loss: 0.0760 - learning_rate: 5.0000e-04
# Epoch 57/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9700 - jaccard_coefficient: 0.8649 - loss: 0.0726
# Epoch 57: loss improved from 0.07476 to 0.07205, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 743ms/step - accuracy: 0.9700 - jaccard_coefficient: 0.8649 - loss: 0.0726 - learning_rate: 5.0000e-04
# Epoch 58/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9716 - jaccard_coefficient: 0.8697 - loss: 0.0698
# Epoch 58: loss improved from 0.07205 to 0.07010, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 743ms/step - accuracy: 0.9716 - jaccard_coefficient: 0.8697 - loss: 0.0698 - learning_rate: 5.0000e-04
# Epoch 59/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9736 - jaccard_coefficient: 0.8778 - loss: 0.0652
# Epoch 59: loss improved from 0.07010 to 0.06672, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 743ms/step - accuracy: 0.9736 - jaccard_coefficient: 0.8777 - loss: 0.0652 - learning_rate: 5.0000e-04
# Epoch 60/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 709ms/step - accuracy: 0.9729 - jaccard_coefficient: 0.8744 - loss: 0.0671
# Epoch 60: loss did not improve from 0.06672
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9729 - jaccard_coefficient: 0.8744 - loss: 0.0671 - learning_rate: 5.0000e-04
# Epoch 61/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9735 - jaccard_coefficient: 0.8796 - loss: 0.0642
# Epoch 61: loss improved from 0.06672 to 0.06335, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 739ms/step - accuracy: 0.9735 - jaccard_coefficient: 0.8796 - loss: 0.0642 - learning_rate: 5.0000e-04
# Epoch 62/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9734 - jaccard_coefficient: 0.8757 - loss: 0.0664
# Epoch 62: loss did not improve from 0.06335
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9734 - jaccard_coefficient: 0.8756 - loss: 0.0664 - learning_rate: 5.0000e-04
# Epoch 63/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9733 - jaccard_coefficient: 0.8742 - loss: 0.0672
# Epoch 63: loss did not improve from 0.06335
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9733 - jaccard_coefficient: 0.8743 - loss: 0.0672 - learning_rate: 5.0000e-04
# Epoch 64/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9747 - jaccard_coefficient: 0.8842 - loss: 0.0615
# Epoch 64: loss improved from 0.06335 to 0.06182, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 743ms/step - accuracy: 0.9747 - jaccard_coefficient: 0.8842 - loss: 0.0615 - learning_rate: 5.0000e-04
# Epoch 65/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9765 - jaccard_coefficient: 0.8908 - loss: 0.0578
# Epoch 65: loss improved from 0.06182 to 0.05910, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9765 - jaccard_coefficient: 0.8908 - loss: 0.0579 - learning_rate: 5.0000e-04
# Epoch 66/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9760 - jaccard_coefficient: 0.8895 - loss: 0.0586
# Epoch 66: loss did not improve from 0.05910
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9760 - jaccard_coefficient: 0.8895 - loss: 0.0586 - learning_rate: 5.0000e-04
# Epoch 67/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9761 - jaccard_coefficient: 0.8885 - loss: 0.0591
# Epoch 67: loss improved from 0.05910 to 0.05822, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 740ms/step - accuracy: 0.9761 - jaccard_coefficient: 0.8885 - loss: 0.0591 - learning_rate: 5.0000e-04
# Epoch 68/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 709ms/step - accuracy: 0.9768 - jaccard_coefficient: 0.8932 - loss: 0.0565
# Epoch 68: loss improved from 0.05822 to 0.05712, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 742ms/step - accuracy: 0.9768 - jaccard_coefficient: 0.8932 - loss: 0.0565 - learning_rate: 5.0000e-04
# Epoch 69/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 709ms/step - accuracy: 0.9759 - jaccard_coefficient: 0.8913 - loss: 0.0576
# Epoch 69: loss improved from 0.05712 to 0.05674, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 743ms/step - accuracy: 0.9759 - jaccard_coefficient: 0.8914 - loss: 0.0576 - learning_rate: 5.0000e-04
# Epoch 70/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9779 - jaccard_coefficient: 0.8979 - loss: 0.0539
# Epoch 70: loss improved from 0.05674 to 0.05502, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 744ms/step - accuracy: 0.9779 - jaccard_coefficient: 0.8979 - loss: 0.0539 - learning_rate: 5.0000e-04
# Epoch 71/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9773 - jaccard_coefficient: 0.8910 - loss: 0.0577
# Epoch 71: loss did not improve from 0.05502
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9773 - jaccard_coefficient: 0.8910 - loss: 0.0577 - learning_rate: 5.0000e-04
# Epoch 72/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9762 - jaccard_coefficient: 0.8897 - loss: 0.0585
# Epoch 72: loss did not improve from 0.05502
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9762 - jaccard_coefficient: 0.8897 - loss: 0.0585 - learning_rate: 5.0000e-04
# Epoch 73/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 709ms/step - accuracy: 0.9773 - jaccard_coefficient: 0.8936 - loss: 0.0563
# Epoch 73: loss did not improve from 0.05502
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9773 - jaccard_coefficient: 0.8936 - loss: 0.0563 - learning_rate: 5.0000e-04
# Epoch 74/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9779 - jaccard_coefficient: 0.9015 - loss: 0.0519
# Epoch 74: loss improved from 0.05502 to 0.05485, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 740ms/step - accuracy: 0.9779 - jaccard_coefficient: 0.9014 - loss: 0.0519 - learning_rate: 5.0000e-04
# Epoch 75/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 709ms/step - accuracy: 0.9770 - jaccard_coefficient: 0.8951 - loss: 0.0555
# Epoch 75: loss did not improve from 0.05485
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9770 - jaccard_coefficient: 0.8951 - loss: 0.0555 - learning_rate: 5.0000e-04
# Epoch 76/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9781 - jaccard_coefficient: 0.8995 - loss: 0.0530
# Epoch 76: loss improved from 0.05485 to 0.05378, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 745ms/step - accuracy: 0.9781 - jaccard_coefficient: 0.8995 - loss: 0.0531 - learning_rate: 5.0000e-04
# Epoch 77/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9787 - jaccard_coefficient: 0.8993 - loss: 0.0531
# Epoch 77: loss improved from 0.05378 to 0.05099, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9787 - jaccard_coefficient: 0.8994 - loss: 0.0530 - learning_rate: 5.0000e-04
# Epoch 78/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9795 - jaccard_coefficient: 0.9062 - loss: 0.0493
# Epoch 78: loss did not improve from 0.05099
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9795 - jaccard_coefficient: 0.9061 - loss: 0.0494 - learning_rate: 5.0000e-04
# Epoch 79/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9776 - jaccard_coefficient: 0.8994 - loss: 0.0530
# Epoch 79: loss did not improve from 0.05099
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9777 - jaccard_coefficient: 0.8994 - loss: 0.0530 - learning_rate: 5.0000e-04
# Epoch 80/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9753 - jaccard_coefficient: 0.8860 - loss: 0.0606
# Epoch 80: loss did not improve from 0.05099
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9753 - jaccard_coefficient: 0.8861 - loss: 0.0605 - learning_rate: 5.0000e-04
# Epoch 81/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9784 - jaccard_coefficient: 0.8992 - loss: 0.0532
# Epoch 81: loss did not improve from 0.05099
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9785 - jaccard_coefficient: 0.8992 - loss: 0.0531 - learning_rate: 5.0000e-04
# Epoch 82/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 709ms/step - accuracy: 0.9797 - jaccard_coefficient: 0.9088 - loss: 0.0478
# Epoch 82: loss improved from 0.05099 to 0.04818, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 743ms/step - accuracy: 0.9798 - jaccard_coefficient: 0.9088 - loss: 0.0478 - learning_rate: 5.0000e-04
# Epoch 83/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9799 - jaccard_coefficient: 0.9028 - loss: 0.0512
# Epoch 83: loss did not improve from 0.04818
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9799 - jaccard_coefficient: 0.9029 - loss: 0.0512 - learning_rate: 5.0000e-04
# Epoch 84/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 709ms/step - accuracy: 0.9792 - jaccard_coefficient: 0.9031 - loss: 0.0511
# Epoch 84: loss did not improve from 0.04818
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9792 - jaccard_coefficient: 0.9031 - loss: 0.0511 - learning_rate: 5.0000e-04
# Epoch 85/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 709ms/step - accuracy: 0.9791 - jaccard_coefficient: 0.9066 - loss: 0.0490
# Epoch 85: loss did not improve from 0.04818
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9791 - jaccard_coefficient: 0.9066 - loss: 0.0490 - learning_rate: 5.0000e-04
# Epoch 86/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9803 - jaccard_coefficient: 0.9084 - loss: 0.0481
# Epoch 86: loss did not improve from 0.04818
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9803 - jaccard_coefficient: 0.9083 - loss: 0.0481 - learning_rate: 5.0000e-04
# Epoch 87/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9805 - jaccard_coefficient: 0.9077 - loss: 0.0485
# Epoch 87: loss improved from 0.04818 to 0.04710, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 742ms/step - accuracy: 0.9805 - jaccard_coefficient: 0.9077 - loss: 0.0485 - learning_rate: 5.0000e-04
# Epoch 88/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 709ms/step - accuracy: 0.9820 - jaccard_coefficient: 0.9153 - loss: 0.0443
# Epoch 88: loss improved from 0.04710 to 0.04391, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 743ms/step - accuracy: 0.9820 - jaccard_coefficient: 0.9153 - loss: 0.0443 - learning_rate: 5.0000e-04
# Epoch 89/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9810 - jaccard_coefficient: 0.9133 - loss: 0.0455
# Epoch 89: loss did not improve from 0.04391
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9811 - jaccard_coefficient: 0.9133 - loss: 0.0454 - learning_rate: 5.0000e-04
# Epoch 90/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 709ms/step - accuracy: 0.9824 - jaccard_coefficient: 0.9152 - loss: 0.0443
# Epoch 90: loss improved from 0.04391 to 0.04356, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 743ms/step - accuracy: 0.9824 - jaccard_coefficient: 0.9152 - loss: 0.0443 - learning_rate: 5.0000e-04
# Epoch 91/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 709ms/step - accuracy: 0.9822 - jaccard_coefficient: 0.9177 - loss: 0.0430
# Epoch 91: loss improved from 0.04356 to 0.04267, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9822 - jaccard_coefficient: 0.9177 - loss: 0.0430 - learning_rate: 5.0000e-04
# Epoch 92/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9827 - jaccard_coefficient: 0.9196 - loss: 0.0420
# Epoch 92: loss improved from 0.04267 to 0.04115, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 740ms/step - accuracy: 0.9827 - jaccard_coefficient: 0.9196 - loss: 0.0420 - learning_rate: 5.0000e-04
# Epoch 93/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9826 - jaccard_coefficient: 0.9191 - loss: 0.0422
# Epoch 93: loss did not improve from 0.04115
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9826 - jaccard_coefficient: 0.9191 - loss: 0.0422 - learning_rate: 5.0000e-04
# Epoch 94/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9825 - jaccard_coefficient: 0.9182 - loss: 0.0427
# Epoch 94: loss did not improve from 0.04115
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9825 - jaccard_coefficient: 0.9182 - loss: 0.0427 - learning_rate: 5.0000e-04
# Epoch 95/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 709ms/step - accuracy: 0.9797 - jaccard_coefficient: 0.9068 - loss: 0.0490
# Epoch 95: loss did not improve from 0.04115
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9797 - jaccard_coefficient: 0.9068 - loss: 0.0489 - learning_rate: 5.0000e-04
# Epoch 96/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9828 - jaccard_coefficient: 0.9205 - loss: 0.0415
# Epoch 96: loss did not improve from 0.04115
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9828 - jaccard_coefficient: 0.9204 - loss: 0.0415 - learning_rate: 5.0000e-04
# Epoch 97/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9833 - jaccard_coefficient: 0.9225 - loss: 0.0404
# Epoch 97: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 97: loss did not improve from 0.04115
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9833 - jaccard_coefficient: 0.9225 - loss: 0.0404 - learning_rate: 5.0000e-04
# Epoch 98/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 709ms/step - accuracy: 0.9843 - jaccard_coefficient: 0.9260 - loss: 0.0385
# Epoch 98: loss improved from 0.04115 to 0.03822, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 744ms/step - accuracy: 0.9843 - jaccard_coefficient: 0.9259 - loss: 0.0385 - learning_rate: 2.5000e-04
# Epoch 99/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9844 - jaccard_coefficient: 0.9263 - loss: 0.0383
# Epoch 99: loss improved from 0.03822 to 0.03766, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 743ms/step - accuracy: 0.9844 - jaccard_coefficient: 0.9263 - loss: 0.0382 - learning_rate: 2.5000e-04
# Epoch 100/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9836 - jaccard_coefficient: 0.9232 - loss: 0.0400
# Epoch 100: loss did not improve from 0.03766
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9836 - jaccard_coefficient: 0.9232 - loss: 0.0400 - learning_rate: 2.5000e-04
# SegUNet output shape: (None, 256, 256, 1)
# ⏱️ Thời gian huấn luyện: 4567.93 giây
# ✅ Accuracy trung bình: 96.34%
# 🔗 Jaccard trung bình: 83.65%

# %%
# Trích xuất dữ liệu từ lịch sử huấn luyện
acc = history.history['accuracy']
loss = history.history['loss']
epochs_range = range(1, len(acc) + 1)

# Vẽ biểu đồ Accuracy và Loss
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Accuracy', color='green')
plt.title('Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Loss', color='red')
plt.title('Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

plt.tight_layout()

# Lưu hình ảnh vào file PNG
plt.savefig('begin_2750.png', dpi=300)

# Hiển thị biểu đồ
plt.show()

# %%
# Hàm hậu xử lý bằng Morphological Operations
def apply_morphology(mask, kernel_size=3, iterations=1):
    """
    Morphological post-processing: closing -> opening để loại bỏ nhiễu và lỗ hổng.
    - kernel_size: Kích thước kernel (7).
    - iterations: Số lần áp dụng phép toán (1 or 2).
    """
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (kernel_size, kernel_size))
    mask = (mask > 0.5).astype(np.uint8)  # Ngưỡng hóa trước

    # Closing để lấp lỗ hổng nhỏ
    closed = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel, iterations=iterations)

    # Opening để loại bỏ nhiễu
    opened = cv2.morphologyEx(closed, cv2.MORPH_OPEN, kernel, iterations=iterations)

    return opened.astype(np.float32)  # Chuyển về float để tính toán metrics

# Đánh giá mô hình gốc (không hậu xử lý)
print("🔍 Đánh giá không hậu xử lý...")
results = segunet.evaluate(test_images_gray_clahe, test_masks, verbose=1)
loss, accuracy, jaccard = results
print(f"Không hậu xử lý - Dice Loss: {loss:.4f}, Accuracy: {accuracy*100:.2f}%, Jaccard: {jaccard*100:.2f}%")

# Dự đoán và hậu xử lý chỉ với Morphological Operations
print("\n🔧 Đánh giá sau Morphology...")
predictions1 = segunet.predict(test_images_gray_clahe)
refined_predictions1 = []

for i in tqdm(range(len(test_images_gray_clahe))):
    pred = predictions1[i].squeeze()

    # Áp dụng Morphological Operations
    morph_pred = apply_morphology(pred, kernel_size=7, iterations=2)

    refined_predictions1.append(morph_pred)


# Chuyển sang numpy array và thêm chiều channel nếu cần
refined_predictions1 = np.expand_dims(np.array(refined_predictions1), axis=-1)

# Tính toán metrics
accuracy_after = np_accuracy(test_masks, refined_predictions1)
jaccard_after = np_jaccard_coefficient(test_masks, refined_predictions1)
loss_after = np_dice_loss(test_masks, refined_predictions1)

print(f"Sau Morphology - Dice Loss: {loss_after:.4f}, Accuracy: {accuracy_after*100:.2f}%, Jaccard: {jaccard_after*100:.2f}%")
# Out:
# 🔍 Đánh giá không hậu xử lý...
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.9520 - jaccard_coefficient: 0.8023 - loss: 0.1117
# E0000 00:00:1751344856.859257     177 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1751344857.099546     177 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1751344858.265851     177 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1751344858.532064     177 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1751344866.176793     177 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1751344866.418428     177 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 0.9516 - jaccard_coefficient: 0.7979 - loss: 0.1145
# Không hậu xử lý - Dice Loss: 0.1502, Accuracy: 94.68%, Jaccard: 74.36%
#
# 🔧 Đánh giá sau Morphology...
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 12s 335ms/step
# 100%|██████████| 825/825 [00:00<00:00, 1579.53it/s]
# Sau Morphology - Dice Loss: 0.1328, Accuracy: 94.67%, Jaccard: 76.55%

# %%
def show_predictions_with_metrics_grid(refined_predictions1,
                                       images, masks,
                                       indices,
                                       save_path):
    num_images = len(indices)
    plt.figure(figsize=(12, 4 * num_images))  # 3 cột x num_images hàng

    for i, idx in enumerate(indices):
        image = images[idx]
        true_mask = masks[idx]
        pred_morph = refined_predictions1[idx]

        # Resize nếu kích thước không khớp
        if pred_morph.shape != true_mask.shape:
            pred_morph = cv2.resize(pred_morph, (true_mask.shape[1], true_mask.shape[0]), interpolation=cv2.INTER_NEAREST)

        # Tính accuracy (giả sử np_accuracy là hàm bạn đã định nghĩa)
        accuracy = np_accuracy(true_mask, pred_morph)

        # Cột 1: Ảnh gốc
        ax1 = plt.subplot(num_images, 3, 3 * i + 1)
        ax1.imshow(image)
        ax1.set_title("Ảnh gốc", fontsize=12)
        ax1.axis('off')

        # Cột 2: Ground Truth Mask
        ax2 = plt.subplot(num_images, 3, 3 * i + 2)
        ax2.imshow(true_mask, cmap='gray')
        ax2.set_title("Ground Truth", fontsize=12)
        ax2.axis('off')

        # Cột 3: Dự đoán hậu xử lý + Accuracy
        ax3 = plt.subplot(num_images, 3, 3 * i + 3)
        ax3.imshow(pred_morph, cmap='gray')
        ax3.set_title(f"Prediction\nAccuracy: {accuracy:.3f}", fontsize=12)
        ax3.axis('off')

    plt.tight_layout()
    plt.savefig(save_path, bbox_inches='tight', dpi=300)
    plt.show()

# %%
show_predictions_with_metrics_grid(
    refined_predictions1=refined_predictions1,
    images=test_images,
    masks=test_masks,
    indices=[722, 191, 54, 700],
        # indices=[72, 555, 461, 700],
    save_path="/kaggle/working/begin_2750.png"
)

# %%
segunet.save('/kaggle/working/model/begin_2750_model.h5')
segunet.save('/kaggle/working/model/begin_2750_model.keras')
