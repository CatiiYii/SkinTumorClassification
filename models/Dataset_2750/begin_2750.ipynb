# %%
import numpy as np
import cv2
from glob import glob
from tqdm import tqdm
import json
import shutil
import os
import pandas as pd
import matplotlib.pyplot as plt
import time
import tensorflow as tf
from tensorflow.keras import backend as K
import tensorflow.keras.backend as K
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, BatchNormalization, ReLU, Concatenate, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.layers import Layer, Input, Conv2D, BatchNormalization, Lambda, Concatenate
print(tf.__version__)
# !pip install git+https://github.com/lucasb-eyer/pydensecrf.git
import pydensecrf.densecrf as dcrf
from pydensecrf.utils import unary_from_softmax, create_pairwise_bilateral
# Out:
# 2025-06-01 21:46:04.636374: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748814364.837642      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748814364.893987      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2.18.0
# Collecting git+https://github.com/lucasb-eyer/pydensecrf.git
#   Cloning https://github.com/lucasb-eyer/pydensecrf.git to /tmp/pip-req-build-l1kcy2wt
#   Running command git clone --filter=blob:none --quiet https://github.com/lucasb-eyer/pydensecrf.git /tmp/pip-req-build-l1kcy2wt
#   Resolved https://github.com/lucasb-eyer/pydensecrf.git to commit 2723c7fa4f2ead16ae1ce3d8afe977724bb8f87f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: pydensecrf
#   Building wheel for pydensecrf (pyproject.toml) ... done
#   Created wheel for pydensecrf: filename=pydensecrf-1.0-cp311-cp311-linux_x86_64.whl size=3440333 sha256=e21f7b7a2fcc59cab91073c55aa725f39f9b51107443fcdca71bab98a3826150
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gbhprx63/wheels/ce/8e/34/6dcfa200a9e2ae3627d8009b8bd1ca9b24512bec50a93304de
# Successfully built pydensecrf
# Installing collected packages: pydensecrf
# Successfully installed pydensecrf-1.0

# %%
def load_isic_dataset(image_path, mask_path, binary_path, csv_file, img_size=(256, 256)):
    """
    Đọc và xử lý dữ liệu từ ISIC 2017 dataset

    Args:
        image_path: Đường dẫn đến thư mục chứa ảnh gốc
        mask_path: Đường dẫn đến thư mục chứa mask
        binary_path: Đường dẫn đến thư mục chứa mask nhị phân
        csv_file: Đường dẫn đầy đủ đến file CSV chứa nhãn
        label_name: Tên cột chứa nhãn trong file CSV
        img_size: Kích thước ảnh đầu ra (width, height)

    Returns:
        images: Numpy array chứa các ảnh đã xử lý
        masks: Numpy array chứa các mask đã xử lý
        binary_masks: Dict chứa mask nhị phân của từng ảnh đã xử lý
        image_ids: List các ID của ảnh
        labels: List các nhãn tương ứng với ảnh
    """

    # Lấy danh sách các file ảnh
    image_files = sorted(glob(os.path.join(image_path, "ISIC_*.jpg")))

    # Khởi tạo lists để lưu dữ liệu
    images = []
    masks = []
    binary_masks = {}
    image_ids = []
    labels = []

    # Đọc file CSV
    csv_data = pd.read_csv(csv_file)
    mel_label = csv_data['melanoma'].astype("int64")

    print("Đang đọc và xử lý dữ liệu...")
    for index, img_path in enumerate(tqdm(image_files)):
        # Lấy image ID
        img_id = os.path.basename(img_path).split('.')[0]
        mask_file = os.path.join(mask_path, f"{img_id}_segmentation.png")
        binary_file = os.path.join(binary_path, f"{img_id}_features.json")

        # Kiểm tra file mask có tồn tại
        if not os.path.exists(mask_file):
            print(f"Không tìm thấy mask cho ảnh mặt nạ {img_id}_segmentation.png")
            continue
        if not os.path.exists(binary_file):
            print(f"Không tìm thấy mask nhị phân cho ảnh {img_id}_features.json")
            continue

        try:


            # Đọc ảnh gốc
            img = cv2.imread(img_path)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Chuyển từ BGR sang RGB


            # Đọc mask
            mask = cv2.imread(mask_file, cv2.IMREAD_GRAYSCALE)

            # Resize ảnh và mask
            img = cv2.resize(img, img_size)
            mask = cv2.resize(mask, img_size)

            # Normalize
            img = img / 255.0
            mask = mask / 255.0

            # Đọc mask nhị phân
            with open(binary_file, 'r') as f:
                binary_masks[img_id] = json.load(f)

            # Lấy nhãn tương ứng
            label = mel_label[index]

            # Thêm vào lists
            images.append(img)
            masks.append(mask)
            image_ids.append(img_id)
            labels.append(label.astype("long"))

        except Exception as e:
            print(f"Lỗi khi xử lý ảnh {img_id}: {str(e)}")
            continue

    # Chuyển sang numpy arrays
    images = np.array(images)
    masks = np.array(masks)[..., np.newaxis]  # Thêm channel dimension cho masks
    labels = np.array(labels)

    print(f"\nĐã đọc thành công {len(images)} ảnh")
    print(f"Shape của images: {images.shape}")
    print(f"Shape của masks: {masks.shape}")
    print(f"Shape của labels: {labels.shape}")

    return images, masks, binary_masks, image_ids, labels

# %%
# Đọc tập training
train_images, train_masks, train_binarys, train_image_ids, train_labels = load_isic_dataset(
    image_path='/kaggle/input/isic-2750/Train_Data',
    mask_path='/kaggle/input/isic-2750/Train_GroundTruth_1',
    binary_path='/kaggle/input/isic-2750/Train_GroundTruth_2',
    csv_file='/kaggle/input/isic-2750/Train_GroundTruth_3.csv',
    img_size=(256, 256)
)
# Out:
# Đang đọc và xử lý dữ liệu...
# 100%|██████████| 1925/1925 [06:13<00:00,  5.15it/s]
# Đã đọc thành công 1925 ảnh
# Shape của images: (1925, 256, 256, 3)
# Shape của masks: (1925, 256, 256, 1)
# Shape của labels: (1925,)

# %%
test_images, test_masks, test_binarys, test_image_ids, test_labels = load_isic_dataset(
    image_path='/kaggle/input/isic-2750/Test_Data',
    mask_path='/kaggle/input/isic-2750/Test_GroundTruth_1',
    binary_path='/kaggle/input/isic-2750/Test_GroundTruth_2',
    csv_file='/kaggle/input/isic-2750/Test_GroundTruth_3.csv',
     # label_name="melanoma",
    img_size=(256, 256)
)
# Out:
# Đang đọc và xử lý dữ liệu...
# 100%|██████████| 825/825 [02:14<00:00,  6.15it/s]
# Đã đọc thành công 825 ảnh
# Shape của images: (825, 256, 256, 3)
# Shape của masks: (825, 256, 256, 1)
# Shape của labels: (825,)

# %%
def iou_metric(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)

    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection
    iou = (intersection + 1e-7) / (union + 1e-7)
    return iou

# %%
def compute_metric(y_true, y_pred, metric='dice_coefficient', smooth=1e-6, is_numpy=False):
    """Tính Dice hoặc Jaccard coefficient/loss cho TensorFlow hoặc NumPy."""
    y_true_f = y_true.flatten() if is_numpy else K.flatten(y_true)
    y_pred_f = y_pred.flatten() if is_numpy else K.flatten(y_pred)
    intersection = np.sum(y_true_f * y_pred_f) if is_numpy else K.sum(y_true_f * y_pred_f)

    if 'dice' in metric:
        sum_fn = np.sum if is_numpy else K.sum
        score = (2. * intersection + smooth) / (sum_fn(y_true_f) + sum_fn(y_pred_f) + smooth)
    elif 'jaccard' in metric:
        sum_fn = np.sum if is_numpy else K.sum
        union = sum_fn(y_true_f) + sum_fn(y_pred_f) - intersection
        score = (intersection + smooth) / (union + smooth)
    else:
        raise ValueError(f"Unsupported metric: {metric}")

    return score if 'coefficient' in metric else 1 - score

# Hàm TensorFlow
def dice_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_coefficient', smooth)

def dice_loss(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_loss', smooth)

def jaccard_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'jaccard_coefficient', smooth)

def jaccard_loss(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'jaccard_loss', smooth)

# Hàm NumPy
def np_accuracy(y_true, y_pred):
    return np.mean(y_true.flatten() == y_pred.flatten())

def np_dice_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_coefficient', smooth, is_numpy=True)

def np_jaccard_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'jaccard_coefficient', smooth, is_numpy=True)

def np_dice_loss(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_loss', smooth, is_numpy=True)

# %%
def CustomSegUNet(input_size=(256, 256, 1)):
    inputs = Input(input_size)

    # Encoder
    c1 = Conv2D(64, (3, 3), padding='same')(inputs)
    c1 = BatchNormalization()(c1)
    c1 = tf.keras.layers.ReLU()(c1)
    c1 = Conv2D(64, (3, 3), padding='same')(c1)
    c1 = BatchNormalization()(c1)
    c1 = tf.keras.layers.ReLU()(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = Conv2D(128, (3, 3), padding='same')(p1)
    c2 = BatchNormalization()(c2)
    c2 = tf.keras.layers.ReLU()(c2)
    c2 = Conv2D(128, (3, 3), padding='same')(c2)
    c2 = BatchNormalization()(c2)
    c2 = tf.keras.layers.ReLU()(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = Conv2D(256, (3, 3), padding='same')(p2)
    c3 = BatchNormalization()(c3)
    c3 = tf.keras.layers.ReLU()(c3)
    c3 = Conv2D(256, (3, 3), padding='same')(c3)
    c3 = BatchNormalization()(c3)
    c3 = tf.keras.layers.ReLU()(c3)
    c3 = Conv2D(256, (3, 3), padding='same')(c3)
    c3 = BatchNormalization()(c3)
    c3 = tf.keras.layers.ReLU()(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    c4 = Conv2D(512, (3, 3), padding='same')(p3)
    c4 = BatchNormalization()(c4)
    c4 = tf.keras.layers.ReLU()(c4)
    c4 = Conv2D(512, (3, 3), padding='same')(c4)
    c4 = BatchNormalization()(c4)
    c4 = tf.keras.layers.ReLU()(c4)
    c4 = Conv2D(512, (3, 3), padding='same')(c4)
    c4 = BatchNormalization()(c4)
    c4 = tf.keras.layers.ReLU()(c4)
    p4 = MaxPooling2D((2, 2))(c4)

    c5 = Conv2D(512, (3, 3), padding='same')(p4)
    c5 = BatchNormalization()(c5)
    c5 = tf.keras.layers.ReLU()(c5)
    c5 = Conv2D(512, (3, 3), padding='same')(c5)
    c5 = BatchNormalization()(c5)
    c5 = tf.keras.layers.ReLU()(c5)
    c5 = Conv2D(512, (3, 3), padding='same')(c5)
    c5 = BatchNormalization()(c5)
    c5 = tf.keras.layers.ReLU()(c5)
    p5 = MaxPooling2D((2, 2))(c5)

    # bottleneck
    c6 = Conv2D(1024, (3, 3), padding='same')(p5)
    c6 = BatchNormalization()(c6)
    c6 = tf.keras.layers.ReLU()(c6)
    c6 = Conv2D(1024, (3, 3), padding='same')(c6)
    c6 = BatchNormalization()(c6)
    c6 = tf.keras.layers.ReLU()(c6)
    c6 = Conv2D(1024, (3, 3), padding='same')(c6)
    c6 = BatchNormalization()(c6)
    c6 = tf.keras.layers.ReLU()(c6)

    # Decoder
    u7 = UpSampling2D((2, 2))(c6)
    u7 = Concatenate()([u7, c5])
    c7 = Conv2D(512, (3, 3), padding='same')(u7)
    c7 = BatchNormalization()(c7)
    c7 = tf.keras.layers.ReLU()(c7)
    c7 = Conv2D(512, (3, 3), padding='same')(c7)
    c7 = BatchNormalization()(c7)
    c7 = tf.keras.layers.ReLU()(c7)
    c7 = Conv2D(512, (3, 3), padding='same')(c7)
    c7 = BatchNormalization()(c7)
    c7 = tf.keras.layers.ReLU()(c7)

    u8 = UpSampling2D((2, 2))(c7)
    u8 = Concatenate()([u8, c4])
    c8 = Conv2D(512, (3, 3), padding='same')(u8)
    c8 = BatchNormalization()(c8)
    c8 = tf.keras.layers.ReLU()(c8)
    c8 = Conv2D(512, (3, 3), padding='same')(c8)
    c8 = BatchNormalization()(c8)
    c8 = tf.keras.layers.ReLU()(c8)
    c8 = Conv2D(256, (3, 3), padding='same')(c8)
    c8 = BatchNormalization()(c8)
    c8 = tf.keras.layers.ReLU()(c8)

    u9 = UpSampling2D((2, 2))(c8)
    u9 = Concatenate()([u9, c3])
    c9 = Conv2D(256, (3, 3), padding='same')(u9)
    c9 = BatchNormalization()(c9)
    c9 = tf.keras.layers.ReLU()(c9)
    c9 = Conv2D(256, (3, 3), padding='same')(c9)
    c9 = BatchNormalization()(c9)
    c9 = tf.keras.layers.ReLU()(c9)
    c9 = Conv2D(128, (3, 3), padding='same')(c9)
    c9 = BatchNormalization()(c9)
    c9 = tf.keras.layers.ReLU()(c9)

    u10 = UpSampling2D((2, 2))(c9)
    u10 = Concatenate()([u10, c2])
    c10 = Conv2D(128, (3, 3), padding='same')(u10)
    c10 = BatchNormalization()(c10)
    c10 = tf.keras.layers.ReLU()(c10)
    c10 = Conv2D(64, (3, 3), padding='same')(c10)
    c10 = BatchNormalization()(c10)
    c10 = tf.keras.layers.ReLU()(c10)

    u11 = UpSampling2D((2, 2))(c10)
    u11 = Concatenate()([u11, c1])
    c11 = Conv2D(64, (3, 3), padding='same')(u11)
    c11 = BatchNormalization()(c11)
    c11 = tf.keras.layers.ReLU()(c11)

    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c11)

    return Model(inputs=inputs, outputs=outputs)

# Khởi tạo và kiểm tra mô hình
if __name__ == "__main__":
    model = CustomSegUNet()
    model.summary()
# Out:
# I0000 00:00:1748814934.375014      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 256, 256, 1)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 256, 256, 64)   │            640 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 256, 256, 64)   │            256 │ conv2d[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu (ReLU)              │ (None, 256, 256, 64)   │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 256, 256, 64)   │         36,928 │ re_lu[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 256, 256, 64)   │            256 │ conv2d_1[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1 (ReLU)            │ (None, 256, 256, 64)   │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 128, 128, 64)   │              0 │ re_lu_1[0][0]          │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 128, 128, 128)  │         73,856 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 128, 128, 128)  │            512 │ conv2d_2[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_2 (ReLU)            │ (None, 128, 128, 128)  │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 128, 128, 128)  │        147,584 │ re_lu_2[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 128, 128, 128)  │            512 │ conv2d_3[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_3 (ReLU)            │ (None, 128, 128, 128)  │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 64, 64, 128)    │              0 │ re_lu_3[0][0]          │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 64, 64, 256)    │        295,168 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 64, 64, 256)    │          1,024 │ conv2d_4[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_4 (ReLU)            │ (None, 64, 64, 256)    │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 64, 64, 256)    │        590,080 │ re_lu_4[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_5     │ (None, 64, 64, 256)    │          1,024 │ conv2d_5[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_5 (ReLU)            │ (None, 64, 64, 256)    │              0 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 64, 64, 256)    │        590,080 │ re_lu_5[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_6     │ (None, 64, 64, 256)    │          1,024 │ conv2d_6[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_6 (ReLU)            │ (None, 64, 64, 256)    │              0 │ batch_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 32, 32, 256)    │              0 │ re_lu_6[0][0]          │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 32, 32, 512)    │      1,180,160 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_7     │ (None, 32, 32, 512)    │          2,048 │ conv2d_7[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_7 (ReLU)            │ (None, 32, 32, 512)    │              0 │ batch_normalization_7… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 32, 32, 512)    │      2,359,808 │ re_lu_7[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_8     │ (None, 32, 32, 512)    │          2,048 │ conv2d_8[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_8 (ReLU)            │ (None, 32, 32, 512)    │              0 │ batch_normalization_8… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 32, 32, 512)    │      2,359,808 │ re_lu_8[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_9     │ (None, 32, 32, 512)    │          2,048 │ conv2d_9[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_9 (ReLU)            │ (None, 32, 32, 512)    │              0 │ batch_normalization_9… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_3           │ (None, 16, 16, 512)    │              0 │ re_lu_9[0][0]          │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_10 (Conv2D)        │ (None, 16, 16, 512)    │      2,359,808 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_10    │ (None, 16, 16, 512)    │          2,048 │ conv2d_10[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_10 (ReLU)           │ (None, 16, 16, 512)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_11 (Conv2D)        │ (None, 16, 16, 512)    │      2,359,808 │ re_lu_10[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_11    │ (None, 16, 16, 512)    │          2,048 │ conv2d_11[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_11 (ReLU)           │ (None, 16, 16, 512)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_12 (Conv2D)        │ (None, 16, 16, 512)    │      2,359,808 │ re_lu_11[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_12    │ (None, 16, 16, 512)    │          2,048 │ conv2d_12[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_12 (ReLU)           │ (None, 16, 16, 512)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_4           │ (None, 8, 8, 512)      │              0 │ re_lu_12[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_13 (Conv2D)        │ (None, 8, 8, 1024)     │      4,719,616 │ max_pooling2d_4[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_13    │ (None, 8, 8, 1024)     │          4,096 │ conv2d_13[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_13 (ReLU)           │ (None, 8, 8, 1024)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_14 (Conv2D)        │ (None, 8, 8, 1024)     │      9,438,208 │ re_lu_13[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_14    │ (None, 8, 8, 1024)     │          4,096 │ conv2d_14[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_14 (ReLU)           │ (None, 8, 8, 1024)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_15 (Conv2D)        │ (None, 8, 8, 1024)     │      9,438,208 │ re_lu_14[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_15    │ (None, 8, 8, 1024)     │          4,096 │ conv2d_15[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_15 (ReLU)           │ (None, 8, 8, 1024)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d             │ (None, 16, 16, 1024)   │              0 │ re_lu_15[0][0]         │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 16, 16, 1536)   │              0 │ up_sampling2d[0][0],   │
# │                           │                        │                │ re_lu_12[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_16 (Conv2D)        │ (None, 16, 16, 512)    │      7,078,400 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_16    │ (None, 16, 16, 512)    │          2,048 │ conv2d_16[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_16 (ReLU)           │ (None, 16, 16, 512)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_17 (Conv2D)        │ (None, 16, 16, 512)    │      2,359,808 │ re_lu_16[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_17    │ (None, 16, 16, 512)    │          2,048 │ conv2d_17[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_17 (ReLU)           │ (None, 16, 16, 512)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_18 (Conv2D)        │ (None, 16, 16, 512)    │      2,359,808 │ re_lu_17[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_18    │ (None, 16, 16, 512)    │          2,048 │ conv2d_18[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_18 (ReLU)           │ (None, 16, 16, 512)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_1           │ (None, 32, 32, 512)    │              0 │ re_lu_18[0][0]         │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 32, 32, 1024)   │              0 │ up_sampling2d_1[0][0], │
# │ (Concatenate)             │                        │                │ re_lu_9[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_19 (Conv2D)        │ (None, 32, 32, 512)    │      4,719,104 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_19    │ (None, 32, 32, 512)    │          2,048 │ conv2d_19[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_19 (ReLU)           │ (None, 32, 32, 512)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_20 (Conv2D)        │ (None, 32, 32, 512)    │      2,359,808 │ re_lu_19[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_20    │ (None, 32, 32, 512)    │          2,048 │ conv2d_20[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_20 (ReLU)           │ (None, 32, 32, 512)    │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_21 (Conv2D)        │ (None, 32, 32, 256)    │      1,179,904 │ re_lu_20[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_21    │ (None, 32, 32, 256)    │          1,024 │ conv2d_21[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_21 (ReLU)           │ (None, 32, 32, 256)    │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_2           │ (None, 64, 64, 256)    │              0 │ re_lu_21[0][0]         │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 64, 64, 512)    │              0 │ up_sampling2d_2[0][0], │
# │ (Concatenate)             │                        │                │ re_lu_6[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_22 (Conv2D)        │ (None, 64, 64, 256)    │      1,179,904 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_22    │ (None, 64, 64, 256)    │          1,024 │ conv2d_22[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_22 (ReLU)           │ (None, 64, 64, 256)    │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_23 (Conv2D)        │ (None, 64, 64, 256)    │        590,080 │ re_lu_22[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_23    │ (None, 64, 64, 256)    │          1,024 │ conv2d_23[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_23 (ReLU)           │ (None, 64, 64, 256)    │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_24 (Conv2D)        │ (None, 64, 64, 128)    │        295,040 │ re_lu_23[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_24    │ (None, 64, 64, 128)    │            512 │ conv2d_24[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_24 (ReLU)           │ (None, 64, 64, 128)    │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_3           │ (None, 128, 128, 128)  │              0 │ re_lu_24[0][0]         │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_3             │ (None, 128, 128, 256)  │              0 │ up_sampling2d_3[0][0], │
# │ (Concatenate)             │                        │                │ re_lu_3[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_25 (Conv2D)        │ (None, 128, 128, 128)  │        295,040 │ concatenate_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_25    │ (None, 128, 128, 128)  │            512 │ conv2d_25[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_25 (ReLU)           │ (None, 128, 128, 128)  │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_26 (Conv2D)        │ (None, 128, 128, 64)   │         73,792 │ re_lu_25[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_26    │ (None, 128, 128, 64)   │            256 │ conv2d_26[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_26 (ReLU)           │ (None, 128, 128, 64)   │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_4           │ (None, 256, 256, 64)   │              0 │ re_lu_26[0][0]         │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_4             │ (None, 256, 256, 128)  │              0 │ up_sampling2d_4[0][0], │
# │ (Concatenate)             │                        │                │ re_lu_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_27 (Conv2D)        │ (None, 256, 256, 64)   │         73,792 │ concatenate_4[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_27    │ (None, 256, 256, 64)   │            256 │ conv2d_27[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_27 (ReLU)           │ (None, 256, 256, 64)   │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_28 (Conv2D)        │ (None, 256, 256, 1)    │             65 │ re_lu_27[0][0]         │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 60,918,145 (232.38 MB)
#  Trainable params: 60,896,129 (232.30 MB)
#  Non-trainable params: 22,016 (86.00 KB)

# %%
class EarlyStoppingByAccuracyChange(tf.keras.callbacks.Callback):
    def __init__(self, monitor='accuracy', threshold=0.00001, patience=3, verbose=0):
        super(EarlyStoppingByAccuracyChange, self).__init__()
        self.monitor = monitor
        self.threshold = threshold
        self.patience = patience
        self.verbose = verbose
        self.wait = 0
        self.best_accuracy = -float('inf')
        self.consecutive_stops = 0

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        current_accuracy = logs.get(self.monitor)
        if current_accuracy is None:
            tf.get_logger().warning(
                'Early stopping requires %s available!', self.monitor
            )
            return

        if current_accuracy > self.best_accuracy:
            self.best_accuracy = current_accuracy
            self.wait = 0
            self.consecutive_stops = 0
        else:
            self.wait += 1
            accuracy_change = current_accuracy - self.best_accuracy
            if abs(accuracy_change) < self.threshold:
                self.consecutive_stops += 1
                if self.consecutive_stops >= self.patience:
                    if self.verbose > 0:
                        print(f"Epoch {epoch+1}: Early stopping triggered due to minimal accuracy change for {self.patience} epochs.")
                    self.model.stop_training = True
            else:
                self.consecutive_stops = 0

# %%
def convert_to_gray_clahe(images):
    grays = []
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))  # tạo đối tượng CLAHE

    for img in images:
        if img.dtype != np.uint8:
            img = (img * 255).astype(np.uint8)
        gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)  # chuyển sang ảnh xám

        img_clahe = clahe.apply(gray)  # áp dụng CLAHE
        grays.append(img_clahe)


    return np.array(grays)

# Gọi hàm
train_images_gray_clahe = convert_to_gray_clahe(train_images)
test_images_gray_clahe = convert_to_gray_clahe(test_images)

# %%
print("Train images shape:", train_images_gray_clahe.shape)
print("Train masks shape:", train_masks.shape)
# Out:
# Train images shape: (1925, 256, 256)
# Train masks shape: (1925, 256, 256, 1)

# %%
import time

initial_lr = 0.001
# lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
#     initial_lr, decay_steps=100000, decay_rate=0.96, staircase=True)

optimizer = Adam(learning_rate=initial_lr)


segunet = CustomSegUNet(input_size=(256, 256, 1))
segunet.compile(
    optimizer=optimizer,
    loss=dice_loss,
    metrics=['accuracy', jaccard_coefficient]
)

# Thiết lập thư mục lưu mô hình
model_checkpoint_dir = 'model'
# os.makedirs(model_checkpoint_dir, exist_ok=True)

checkpoint_path = os.path.join(model_checkpoint_dir, 'cp.ckpt')

checkpoint_callback = ModelCheckpoint(
    filepath=os.path.join(model_checkpoint_dir, 'begin.weights.h5'),
    save_weights_only=True,
    monitor='loss',
    mode='min',
    save_best_only=True,
    verbose=1
)

# Callback theo dõi train accuracy thay vì validation loss/accuracy
early_stopping = EarlyStoppingByAccuracyChange(
    monitor='accuracy',
    threshold=0.00001,
    patience=10,
    verbose=1
)
# ReduceLROnPlateau Callback
lr_reduction = ReduceLROnPlateau(monitor='loss',
                                  patience=5,
                                  verbose=1,
                                  factor=0.5,
                                  min_lr=0.00001)


# --- Tính thời gian huấn luyện ---
start_time = time.time()

# Huấn luyện mô hình
history = segunet.fit(
    train_images_gray_clahe, train_masks,
    batch_size=32,
    epochs=100,
    callbacks=[early_stopping, lr_reduction, checkpoint_callback]
)

end_time = time.time()
training_time = end_time - start_time

# --- Tính trung bình Accuracy và Jaccard ---
avg_accuracy = np.mean(history.history['accuracy'])
avg_jaccard = np.mean(history.history['jaccard_coefficient'])

# --- In kết quả ---
print("SegUNet output shape:", segunet.output_shape)
print(f"⏱️ Thời gian huấn luyện: {training_time:.2f} giây")
print(f"✅ Accuracy trung bình: {avg_accuracy*100:.2f}%")
print(f"🔗 Jaccard trung bình: {avg_jaccard*100:.2f}%")
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1748814965.815721     180 service.cc:148] XLA service 0x7e5060005710 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1748814965.816380     180 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1748814968.221434     180 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-06-01 21:56:36.899320: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng2{k2=3,k3=0} for conv (f32[32,128,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,64,256,256]{3,2,1,0}, f32[64,128,3,3]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-06-01 21:56:36.902581: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.003369708s
# Trying algorithm eng2{k2=3,k3=0} for conv (f32[32,128,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,64,256,256]{3,2,1,0}, f32[64,128,3,3]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# I0000 00:00:1748815037.724594     180 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 711ms/step - accuracy: 0.8414 - jaccard_coefficient: 0.4544 - loss: 0.3905
# E0000 00:00:1748815084.042881     177 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1748815084.275716     177 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1748815084.833836     177 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1748815085.089386     177 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1748815087.820219     177 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1748815088.052941     177 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8420 - jaccard_coefficient: 0.4555 - loss: 0.3894
# Epoch 1: loss improved from inf to 0.32018, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 165s 1s/step - accuracy: 0.8425 - jaccard_coefficient: 0.4566 - loss: 0.3883 - learning_rate: 0.0010
# Epoch 2/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9029 - jaccard_coefficient: 0.6007 - loss: 0.2520
# Epoch 2: loss improved from 0.32018 to 0.24003, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 738ms/step - accuracy: 0.9030 - jaccard_coefficient: 0.6009 - loss: 0.2518 - learning_rate: 0.0010
# Epoch 3/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9054 - jaccard_coefficient: 0.6100 - loss: 0.2455
# Epoch 3: loss improved from 0.24003 to 0.22820, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9055 - jaccard_coefficient: 0.6104 - loss: 0.2452 - learning_rate: 0.0010
# Epoch 4/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9199 - jaccard_coefficient: 0.6610 - loss: 0.2049
# Epoch 4: loss improved from 0.22820 to 0.20512, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9199 - jaccard_coefficient: 0.6609 - loss: 0.2049 - learning_rate: 0.0010
# Epoch 5/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9200 - jaccard_coefficient: 0.6592 - loss: 0.2074
# Epoch 5: loss improved from 0.20512 to 0.20067, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9200 - jaccard_coefficient: 0.6594 - loss: 0.2073 - learning_rate: 0.0010
# Epoch 6/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9243 - jaccard_coefficient: 0.6830 - loss: 0.1900
# Epoch 6: loss improved from 0.20067 to 0.18556, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9244 - jaccard_coefficient: 0.6831 - loss: 0.1900 - learning_rate: 0.0010
# Epoch 7/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9290 - jaccard_coefficient: 0.6970 - loss: 0.1802
# Epoch 7: loss improved from 0.18556 to 0.18372, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 738ms/step - accuracy: 0.9290 - jaccard_coefficient: 0.6969 - loss: 0.1802 - learning_rate: 0.0010
# Epoch 8/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9344 - jaccard_coefficient: 0.7103 - loss: 0.1702
# Epoch 8: loss improved from 0.18372 to 0.16496, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 738ms/step - accuracy: 0.9344 - jaccard_coefficient: 0.7104 - loss: 0.1701 - learning_rate: 0.0010
# Epoch 9/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9356 - jaccard_coefficient: 0.7265 - loss: 0.1596
# Epoch 9: loss improved from 0.16496 to 0.16071, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 738ms/step - accuracy: 0.9356 - jaccard_coefficient: 0.7265 - loss: 0.1597 - learning_rate: 0.0010
# Epoch 10/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9333 - jaccard_coefficient: 0.7195 - loss: 0.1641
# Epoch 10: loss improved from 0.16071 to 0.15951, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 739ms/step - accuracy: 0.9334 - jaccard_coefficient: 0.7196 - loss: 0.1641 - learning_rate: 0.0010
# Epoch 11/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9423 - jaccard_coefficient: 0.7497 - loss: 0.1438
# Epoch 11: loss improved from 0.15951 to 0.15059, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 739ms/step - accuracy: 0.9423 - jaccard_coefficient: 0.7495 - loss: 0.1439 - learning_rate: 0.0010
# Epoch 12/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9383 - jaccard_coefficient: 0.7415 - loss: 0.1495
# Epoch 12: loss improved from 0.15059 to 0.14874, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 739ms/step - accuracy: 0.9383 - jaccard_coefficient: 0.7415 - loss: 0.1495 - learning_rate: 0.0010
# Epoch 13/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9433 - jaccard_coefficient: 0.7486 - loss: 0.1447
# Epoch 13: loss improved from 0.14874 to 0.14632, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 739ms/step - accuracy: 0.9433 - jaccard_coefficient: 0.7486 - loss: 0.1447 - learning_rate: 0.0010
# Epoch 14/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9435 - jaccard_coefficient: 0.7503 - loss: 0.1436
# Epoch 14: loss improved from 0.14632 to 0.14022, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 738ms/step - accuracy: 0.9435 - jaccard_coefficient: 0.7504 - loss: 0.1435 - learning_rate: 0.0010
# Epoch 15/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9419 - jaccard_coefficient: 0.7500 - loss: 0.1435
# Epoch 15: loss improved from 0.14022 to 0.13800, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 739ms/step - accuracy: 0.9419 - jaccard_coefficient: 0.7501 - loss: 0.1434 - learning_rate: 0.0010
# Epoch 16/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9453 - jaccard_coefficient: 0.7607 - loss: 0.1370
# Epoch 16: loss did not improve from 0.13800
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 704ms/step - accuracy: 0.9453 - jaccard_coefficient: 0.7606 - loss: 0.1370 - learning_rate: 0.0010
# Epoch 17/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9456 - jaccard_coefficient: 0.7625 - loss: 0.1354
# Epoch 17: loss improved from 0.13800 to 0.13718, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 739ms/step - accuracy: 0.9456 - jaccard_coefficient: 0.7625 - loss: 0.1354 - learning_rate: 0.0010
# Epoch 18/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9457 - jaccard_coefficient: 0.7599 - loss: 0.1375
# Epoch 18: loss improved from 0.13718 to 0.13246, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 739ms/step - accuracy: 0.9457 - jaccard_coefficient: 0.7600 - loss: 0.1374 - learning_rate: 0.0010
# Epoch 19/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9337 - jaccard_coefficient: 0.7271 - loss: 0.1593
# Epoch 19: loss did not improve from 0.13246
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 704ms/step - accuracy: 0.9338 - jaccard_coefficient: 0.7271 - loss: 0.1593 - learning_rate: 0.0010
# Epoch 20/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9461 - jaccard_coefficient: 0.7669 - loss: 0.1328
# Epoch 20: loss did not improve from 0.13246
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 704ms/step - accuracy: 0.9461 - jaccard_coefficient: 0.7668 - loss: 0.1328 - learning_rate: 0.0010
# Epoch 21/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9446 - jaccard_coefficient: 0.7590 - loss: 0.1379
# Epoch 21: loss did not improve from 0.13246
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 704ms/step - accuracy: 0.9446 - jaccard_coefficient: 0.7591 - loss: 0.1378 - learning_rate: 0.0010
# Epoch 22/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9476 - jaccard_coefficient: 0.7704 - loss: 0.1304
# Epoch 22: loss did not improve from 0.13246
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 704ms/step - accuracy: 0.9476 - jaccard_coefficient: 0.7703 - loss: 0.1305 - learning_rate: 0.0010
# Epoch 23/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9481 - jaccard_coefficient: 0.7719 - loss: 0.1294
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 23: loss did not improve from 0.13246
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 704ms/step - accuracy: 0.9481 - jaccard_coefficient: 0.7718 - loss: 0.1295 - learning_rate: 0.0010
# Epoch 24/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9526 - jaccard_coefficient: 0.7915 - loss: 0.1172
# Epoch 24: loss improved from 0.13246 to 0.12061, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 740ms/step - accuracy: 0.9526 - jaccard_coefficient: 0.7915 - loss: 0.1172 - learning_rate: 5.0000e-04
# Epoch 25/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9542 - jaccard_coefficient: 0.7954 - loss: 0.1146
# Epoch 25: loss improved from 0.12061 to 0.11445, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 739ms/step - accuracy: 0.9542 - jaccard_coefficient: 0.7954 - loss: 0.1146 - learning_rate: 5.0000e-04
# Epoch 26/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9546 - jaccard_coefficient: 0.8024 - loss: 0.1102
# Epoch 26: loss did not improve from 0.11445
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 704ms/step - accuracy: 0.9545 - jaccard_coefficient: 0.8022 - loss: 0.1104 - learning_rate: 5.0000e-04
# Epoch 27/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9549 - jaccard_coefficient: 0.8011 - loss: 0.1108
# Epoch 27: loss improved from 0.11445 to 0.11115, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 739ms/step - accuracy: 0.9549 - jaccard_coefficient: 0.8011 - loss: 0.1108 - learning_rate: 5.0000e-04
# Epoch 28/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9552 - jaccard_coefficient: 0.8029 - loss: 0.1100
# Epoch 28: loss improved from 0.11115 to 0.11084, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 739ms/step - accuracy: 0.9552 - jaccard_coefficient: 0.8028 - loss: 0.1100 - learning_rate: 5.0000e-04
# Epoch 29/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9534 - jaccard_coefficient: 0.7938 - loss: 0.1156
# Epoch 29: loss did not improve from 0.11084
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 704ms/step - accuracy: 0.9535 - jaccard_coefficient: 0.7939 - loss: 0.1156 - learning_rate: 5.0000e-04
# Epoch 30/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9522 - jaccard_coefficient: 0.7935 - loss: 0.1158
# Epoch 30: loss improved from 0.11084 to 0.10905, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 740ms/step - accuracy: 0.9523 - jaccard_coefficient: 0.7936 - loss: 0.1157 - learning_rate: 5.0000e-04
# Epoch 31/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9585 - jaccard_coefficient: 0.8147 - loss: 0.1023
# Epoch 31: loss improved from 0.10905 to 0.10310, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 740ms/step - accuracy: 0.9585 - jaccard_coefficient: 0.8147 - loss: 0.1023 - learning_rate: 5.0000e-04
# Epoch 32/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9590 - jaccard_coefficient: 0.8183 - loss: 0.1003
# Epoch 32: loss did not improve from 0.10310
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 705ms/step - accuracy: 0.9589 - jaccard_coefficient: 0.8182 - loss: 0.1004 - learning_rate: 5.0000e-04
# Epoch 33/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9570 - jaccard_coefficient: 0.8046 - loss: 0.1087
# Epoch 33: loss did not improve from 0.10310
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 704ms/step - accuracy: 0.9570 - jaccard_coefficient: 0.8047 - loss: 0.1087 - learning_rate: 5.0000e-04
# Epoch 34/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9557 - jaccard_coefficient: 0.8037 - loss: 0.1092
# Epoch 34: loss did not improve from 0.10310
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 704ms/step - accuracy: 0.9558 - jaccard_coefficient: 0.8038 - loss: 0.1091 - learning_rate: 5.0000e-04
# Epoch 35/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9556 - jaccard_coefficient: 0.8024 - loss: 0.1103
# Epoch 35: loss did not improve from 0.10310
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 704ms/step - accuracy: 0.9556 - jaccard_coefficient: 0.8025 - loss: 0.1102 - learning_rate: 5.0000e-04
# Epoch 36/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9552 - jaccard_coefficient: 0.8016 - loss: 0.1107
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 36: loss did not improve from 0.10310
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 704ms/step - accuracy: 0.9552 - jaccard_coefficient: 0.8017 - loss: 0.1107 - learning_rate: 5.0000e-04
# Epoch 37/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9598 - jaccard_coefficient: 0.8216 - loss: 0.0985
# Epoch 37: loss improved from 0.10310 to 0.09602, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 740ms/step - accuracy: 0.9599 - jaccard_coefficient: 0.8216 - loss: 0.0985 - learning_rate: 2.5000e-04
# Epoch 38/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9629 - jaccard_coefficient: 0.8275 - loss: 0.0947
# Epoch 38: loss improved from 0.09602 to 0.09344, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9629 - jaccard_coefficient: 0.8275 - loss: 0.0947 - learning_rate: 2.5000e-04
# Epoch 39/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9618 - jaccard_coefficient: 0.8300 - loss: 0.0932
# Epoch 39: loss improved from 0.09344 to 0.09313, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 740ms/step - accuracy: 0.9618 - jaccard_coefficient: 0.8300 - loss: 0.0932 - learning_rate: 2.5000e-04
# Epoch 40/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9641 - jaccard_coefficient: 0.8348 - loss: 0.0903
# Epoch 40: loss improved from 0.09313 to 0.09251, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 740ms/step - accuracy: 0.9641 - jaccard_coefficient: 0.8348 - loss: 0.0903 - learning_rate: 2.5000e-04
# Epoch 41/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9636 - jaccard_coefficient: 0.8373 - loss: 0.0889
# Epoch 41: loss improved from 0.09251 to 0.09031, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 740ms/step - accuracy: 0.9636 - jaccard_coefficient: 0.8373 - loss: 0.0889 - learning_rate: 2.5000e-04
# Epoch 42/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9636 - jaccard_coefficient: 0.8356 - loss: 0.0899
# Epoch 42: loss did not improve from 0.09031
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 705ms/step - accuracy: 0.9636 - jaccard_coefficient: 0.8356 - loss: 0.0899 - learning_rate: 2.5000e-04
# Epoch 43/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9670 - jaccard_coefficient: 0.8467 - loss: 0.0833
# Epoch 43: loss improved from 0.09031 to 0.08680, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 739ms/step - accuracy: 0.9670 - jaccard_coefficient: 0.8466 - loss: 0.0834 - learning_rate: 2.5000e-04
# Epoch 44/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9645 - jaccard_coefficient: 0.8405 - loss: 0.0870
# Epoch 44: loss improved from 0.08680 to 0.08534, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 735ms/step - accuracy: 0.9645 - jaccard_coefficient: 0.8405 - loss: 0.0869 - learning_rate: 2.5000e-04
# Epoch 45/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9644 - jaccard_coefficient: 0.8406 - loss: 0.0867
# Epoch 45: loss did not improve from 0.08534
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 704ms/step - accuracy: 0.9644 - jaccard_coefficient: 0.8406 - loss: 0.0867 - learning_rate: 2.5000e-04
# Epoch 46/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9666 - jaccard_coefficient: 0.8386 - loss: 0.0880
# Epoch 46: loss did not improve from 0.08534
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 704ms/step - accuracy: 0.9666 - jaccard_coefficient: 0.8386 - loss: 0.0880 - learning_rate: 2.5000e-04
# Epoch 47/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9660 - jaccard_coefficient: 0.8467 - loss: 0.0835
# Epoch 47: loss did not improve from 0.08534
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 704ms/step - accuracy: 0.9660 - jaccard_coefficient: 0.8465 - loss: 0.0836 - learning_rate: 2.5000e-04
# Epoch 48/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9634 - jaccard_coefficient: 0.8375 - loss: 0.0887
# Epoch 48: loss did not improve from 0.08534
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 705ms/step - accuracy: 0.9634 - jaccard_coefficient: 0.8376 - loss: 0.0887 - learning_rate: 2.5000e-04
# Epoch 49/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9647 - jaccard_coefficient: 0.8436 - loss: 0.0851
# Epoch 49: loss improved from 0.08534 to 0.08369, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 740ms/step - accuracy: 0.9647 - jaccard_coefficient: 0.8437 - loss: 0.0851 - learning_rate: 2.5000e-04
# Epoch 50/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 705ms/step - accuracy: 0.9665 - jaccard_coefficient: 0.8485 - loss: 0.0822
# Epoch 50: loss improved from 0.08369 to 0.08291, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 738ms/step - accuracy: 0.9665 - jaccard_coefficient: 0.8485 - loss: 0.0822 - learning_rate: 2.5000e-04
# Epoch 51/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9684 - jaccard_coefficient: 0.8498 - loss: 0.0813
# Epoch 51: loss improved from 0.08291 to 0.08284, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9684 - jaccard_coefficient: 0.8498 - loss: 0.0814 - learning_rate: 2.5000e-04
# Epoch 52/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9685 - jaccard_coefficient: 0.8529 - loss: 0.0795
# Epoch 52: loss improved from 0.08284 to 0.08265, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 739ms/step - accuracy: 0.9684 - jaccard_coefficient: 0.8528 - loss: 0.0795 - learning_rate: 2.5000e-04
# Epoch 53/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 705ms/step - accuracy: 0.9680 - jaccard_coefficient: 0.8533 - loss: 0.0793
# Epoch 53: loss improved from 0.08265 to 0.08236, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 742ms/step - accuracy: 0.9680 - jaccard_coefficient: 0.8532 - loss: 0.0793 - learning_rate: 2.5000e-04
# Epoch 54/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 705ms/step - accuracy: 0.9680 - jaccard_coefficient: 0.8562 - loss: 0.0777
# Epoch 54: loss improved from 0.08236 to 0.07864, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9680 - jaccard_coefficient: 0.8562 - loss: 0.0777 - learning_rate: 2.5000e-04
# Epoch 55/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9687 - jaccard_coefficient: 0.8564 - loss: 0.0775
# Epoch 55: loss improved from 0.07864 to 0.07817, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9687 - jaccard_coefficient: 0.8564 - loss: 0.0775 - learning_rate: 2.5000e-04
# Epoch 56/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9678 - jaccard_coefficient: 0.8573 - loss: 0.0770
# Epoch 56: loss improved from 0.07817 to 0.07799, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 740ms/step - accuracy: 0.9678 - jaccard_coefficient: 0.8573 - loss: 0.0770 - learning_rate: 2.5000e-04
# Epoch 57/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 705ms/step - accuracy: 0.9691 - jaccard_coefficient: 0.8547 - loss: 0.0786
# Epoch 57: loss did not improve from 0.07799
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 705ms/step - accuracy: 0.9691 - jaccard_coefficient: 0.8547 - loss: 0.0786 - learning_rate: 2.5000e-04
# Epoch 58/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 705ms/step - accuracy: 0.9688 - jaccard_coefficient: 0.8530 - loss: 0.0795
# Epoch 58: loss did not improve from 0.07799
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 705ms/step - accuracy: 0.9688 - jaccard_coefficient: 0.8530 - loss: 0.0795 - learning_rate: 2.5000e-04
# Epoch 59/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9711 - jaccard_coefficient: 0.8612 - loss: 0.0748
# Epoch 59: loss improved from 0.07799 to 0.07590, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 736ms/step - accuracy: 0.9710 - jaccard_coefficient: 0.8611 - loss: 0.0748 - learning_rate: 2.5000e-04
# Epoch 60/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9668 - jaccard_coefficient: 0.8467 - loss: 0.0833
# Epoch 60: loss did not improve from 0.07590
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 704ms/step - accuracy: 0.9668 - jaccard_coefficient: 0.8469 - loss: 0.0832 - learning_rate: 2.5000e-04
# Epoch 61/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9692 - jaccard_coefficient: 0.8559 - loss: 0.0780
# Epoch 61: loss did not improve from 0.07590
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 704ms/step - accuracy: 0.9692 - jaccard_coefficient: 0.8559 - loss: 0.0780 - learning_rate: 2.5000e-04
# Epoch 62/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9706 - jaccard_coefficient: 0.8648 - loss: 0.0726
# Epoch 62: loss improved from 0.07590 to 0.07566, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 734ms/step - accuracy: 0.9706 - jaccard_coefficient: 0.8648 - loss: 0.0726 - learning_rate: 2.5000e-04
# Epoch 63/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9698 - jaccard_coefficient: 0.8661 - loss: 0.0719
# Epoch 63: loss improved from 0.07566 to 0.07380, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9698 - jaccard_coefficient: 0.8660 - loss: 0.0720 - learning_rate: 2.5000e-04
# Epoch 64/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9716 - jaccard_coefficient: 0.8715 - loss: 0.0688
# Epoch 64: loss improved from 0.07380 to 0.07265, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 739ms/step - accuracy: 0.9716 - jaccard_coefficient: 0.8713 - loss: 0.0688 - learning_rate: 2.5000e-04
# Epoch 65/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9650 - jaccard_coefficient: 0.8439 - loss: 0.0849
# Epoch 65: loss did not improve from 0.07265
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 703ms/step - accuracy: 0.9650 - jaccard_coefficient: 0.8440 - loss: 0.0849 - learning_rate: 2.5000e-04
# Epoch 66/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9688 - jaccard_coefficient: 0.8599 - loss: 0.0755
# Epoch 66: loss did not improve from 0.07265
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 703ms/step - accuracy: 0.9688 - jaccard_coefficient: 0.8600 - loss: 0.0755 - learning_rate: 2.5000e-04
# Epoch 67/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9709 - jaccard_coefficient: 0.8689 - loss: 0.0704
# Epoch 67: loss did not improve from 0.07265
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 703ms/step - accuracy: 0.9709 - jaccard_coefficient: 0.8688 - loss: 0.0704 - learning_rate: 2.5000e-04
# Epoch 68/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9699 - jaccard_coefficient: 0.8592 - loss: 0.0759
# Epoch 68: loss did not improve from 0.07265
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 704ms/step - accuracy: 0.9699 - jaccard_coefficient: 0.8593 - loss: 0.0759 - learning_rate: 2.5000e-04
# Epoch 69/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9694 - jaccard_coefficient: 0.8632 - loss: 0.0736
# Epoch 69: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 69: loss improved from 0.07265 to 0.07264, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 735ms/step - accuracy: 0.9694 - jaccard_coefficient: 0.8632 - loss: 0.0736 - learning_rate: 2.5000e-04
# Epoch 70/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9730 - jaccard_coefficient: 0.8750 - loss: 0.0669
# Epoch 70: loss improved from 0.07264 to 0.06674, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9730 - jaccard_coefficient: 0.8750 - loss: 0.0668 - learning_rate: 1.2500e-04
# Epoch 71/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9732 - jaccard_coefficient: 0.8788 - loss: 0.0646
# Epoch 71: loss improved from 0.06674 to 0.06478, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 735ms/step - accuracy: 0.9732 - jaccard_coefficient: 0.8788 - loss: 0.0646 - learning_rate: 1.2500e-04
# Epoch 72/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9733 - jaccard_coefficient: 0.8808 - loss: 0.0635
# Epoch 72: loss improved from 0.06478 to 0.06464, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 735ms/step - accuracy: 0.9733 - jaccard_coefficient: 0.8807 - loss: 0.0635 - learning_rate: 1.2500e-04
# Epoch 73/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9728 - jaccard_coefficient: 0.8798 - loss: 0.0641
# Epoch 73: loss improved from 0.06464 to 0.06460, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 736ms/step - accuracy: 0.9728 - jaccard_coefficient: 0.8798 - loss: 0.0641 - learning_rate: 1.2500e-04
# Epoch 74/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9739 - jaccard_coefficient: 0.8834 - loss: 0.0620
# Epoch 74: loss improved from 0.06460 to 0.06352, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 736ms/step - accuracy: 0.9739 - jaccard_coefficient: 0.8834 - loss: 0.0620 - learning_rate: 1.2500e-04
# Epoch 75/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9741 - jaccard_coefficient: 0.8804 - loss: 0.0637
# Epoch 75: loss did not improve from 0.06352
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 703ms/step - accuracy: 0.9741 - jaccard_coefficient: 0.8804 - loss: 0.0637 - learning_rate: 1.2500e-04
# Epoch 76/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9718 - jaccard_coefficient: 0.8695 - loss: 0.0700
# Epoch 76: loss did not improve from 0.06352
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 704ms/step - accuracy: 0.9718 - jaccard_coefficient: 0.8695 - loss: 0.0700 - learning_rate: 1.2500e-04
# Epoch 77/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9729 - jaccard_coefficient: 0.8761 - loss: 0.0662
# Epoch 77: loss did not improve from 0.06352
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 703ms/step - accuracy: 0.9729 - jaccard_coefficient: 0.8762 - loss: 0.0662 - learning_rate: 1.2500e-04
# Epoch 78/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9739 - jaccard_coefficient: 0.8798 - loss: 0.0641
# Epoch 78: loss did not improve from 0.06352
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 704ms/step - accuracy: 0.9739 - jaccard_coefficient: 0.8798 - loss: 0.0641 - learning_rate: 1.2500e-04
# Epoch 79/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9745 - jaccard_coefficient: 0.8850 - loss: 0.0611
# Epoch 79: loss improved from 0.06352 to 0.06244, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 739ms/step - accuracy: 0.9745 - jaccard_coefficient: 0.8850 - loss: 0.0611 - learning_rate: 1.2500e-04
# Epoch 80/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9742 - jaccard_coefficient: 0.8810 - loss: 0.0634
# Epoch 80: loss did not improve from 0.06244
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 703ms/step - accuracy: 0.9742 - jaccard_coefficient: 0.8810 - loss: 0.0634 - learning_rate: 1.2500e-04
# Epoch 81/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9746 - jaccard_coefficient: 0.8795 - loss: 0.0644
# Epoch 81: loss did not improve from 0.06244
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 704ms/step - accuracy: 0.9746 - jaccard_coefficient: 0.8796 - loss: 0.0643 - learning_rate: 1.2500e-04
# Epoch 82/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9750 - jaccard_coefficient: 0.8880 - loss: 0.0594
# Epoch 82: loss improved from 0.06244 to 0.06093, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 739ms/step - accuracy: 0.9750 - jaccard_coefficient: 0.8879 - loss: 0.0594 - learning_rate: 1.2500e-04
# Epoch 83/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9752 - jaccard_coefficient: 0.8860 - loss: 0.0605
# Epoch 83: loss improved from 0.06093 to 0.06031, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 734ms/step - accuracy: 0.9752 - jaccard_coefficient: 0.8860 - loss: 0.0605 - learning_rate: 1.2500e-04
# Epoch 84/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9754 - jaccard_coefficient: 0.8871 - loss: 0.0599
# Epoch 84: loss improved from 0.06031 to 0.06029, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9754 - jaccard_coefficient: 0.8870 - loss: 0.0599 - learning_rate: 1.2500e-04
# Epoch 85/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9763 - jaccard_coefficient: 0.8874 - loss: 0.0598
# Epoch 85: loss improved from 0.06029 to 0.05890, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 738ms/step - accuracy: 0.9763 - jaccard_coefficient: 0.8874 - loss: 0.0598 - learning_rate: 1.2500e-04
# Epoch 86/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9757 - jaccard_coefficient: 0.8886 - loss: 0.0591
# Epoch 86: loss improved from 0.05890 to 0.05765, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 735ms/step - accuracy: 0.9757 - jaccard_coefficient: 0.8886 - loss: 0.0591 - learning_rate: 1.2500e-04
# Epoch 87/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9754 - jaccard_coefficient: 0.8864 - loss: 0.0604
# Epoch 87: loss did not improve from 0.05765
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 703ms/step - accuracy: 0.9755 - jaccard_coefficient: 0.8865 - loss: 0.0603 - learning_rate: 1.2500e-04
# Epoch 88/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9759 - jaccard_coefficient: 0.8907 - loss: 0.0579
# Epoch 88: loss improved from 0.05765 to 0.05763, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 736ms/step - accuracy: 0.9759 - jaccard_coefficient: 0.8907 - loss: 0.0579 - learning_rate: 1.2500e-04
# Epoch 89/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9768 - jaccard_coefficient: 0.8897 - loss: 0.0584
# Epoch 89: loss did not improve from 0.05763
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 703ms/step - accuracy: 0.9768 - jaccard_coefficient: 0.8897 - loss: 0.0584 - learning_rate: 1.2500e-04
# Epoch 90/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9763 - jaccard_coefficient: 0.8929 - loss: 0.0567
# Epoch 90: loss did not improve from 0.05763
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 704ms/step - accuracy: 0.9763 - jaccard_coefficient: 0.8928 - loss: 0.0567 - learning_rate: 1.2500e-04
# Epoch 91/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9751 - jaccard_coefficient: 0.8896 - loss: 0.0586
# Epoch 91: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 91: loss did not improve from 0.05763
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 704ms/step - accuracy: 0.9752 - jaccard_coefficient: 0.8896 - loss: 0.0586 - learning_rate: 1.2500e-04
# Epoch 92/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9769 - jaccard_coefficient: 0.8927 - loss: 0.0568
# Epoch 92: loss improved from 0.05763 to 0.05626, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 739ms/step - accuracy: 0.9769 - jaccard_coefficient: 0.8927 - loss: 0.0568 - learning_rate: 6.2500e-05
# Epoch 93/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9782 - jaccard_coefficient: 0.8961 - loss: 0.0549
# Epoch 93: loss improved from 0.05626 to 0.05451, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 735ms/step - accuracy: 0.9782 - jaccard_coefficient: 0.8961 - loss: 0.0549 - learning_rate: 6.2500e-05
# Epoch 94/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9783 - jaccard_coefficient: 0.8990 - loss: 0.0533
# Epoch 94: loss improved from 0.05451 to 0.05309, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 738ms/step - accuracy: 0.9783 - jaccard_coefficient: 0.8990 - loss: 0.0533 - learning_rate: 6.2500e-05
# Epoch 95/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9764 - jaccard_coefficient: 0.8941 - loss: 0.0561
# Epoch 95: loss did not improve from 0.05309
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 704ms/step - accuracy: 0.9764 - jaccard_coefficient: 0.8941 - loss: 0.0560 - learning_rate: 6.2500e-05
# Epoch 96/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9787 - jaccard_coefficient: 0.9011 - loss: 0.0521
# Epoch 96: loss did not improve from 0.05309
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 704ms/step - accuracy: 0.9787 - jaccard_coefficient: 0.9011 - loss: 0.0521 - learning_rate: 6.2500e-05
# Epoch 97/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9790 - jaccard_coefficient: 0.9055 - loss: 0.0497
# Epoch 97: loss improved from 0.05309 to 0.05271, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9790 - jaccard_coefficient: 0.9053 - loss: 0.0497 - learning_rate: 6.2500e-05
# Epoch 98/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9782 - jaccard_coefficient: 0.8960 - loss: 0.0550
# Epoch 98: loss did not improve from 0.05271
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 704ms/step - accuracy: 0.9782 - jaccard_coefficient: 0.8960 - loss: 0.0550 - learning_rate: 6.2500e-05
# Epoch 99/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9791 - jaccard_coefficient: 0.9036 - loss: 0.0507
# Epoch 99: loss improved from 0.05271 to 0.05244, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 736ms/step - accuracy: 0.9791 - jaccard_coefficient: 0.9035 - loss: 0.0507 - learning_rate: 6.2500e-05
# Epoch 100/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9788 - jaccard_coefficient: 0.9003 - loss: 0.0525
# Epoch 100: loss improved from 0.05244 to 0.05212, saving model to model/begin.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 734ms/step - accuracy: 0.9788 - jaccard_coefficient: 0.9004 - loss: 0.0525 - learning_rate: 6.2500e-05
# SegUNet output shape: (None, 256, 256, 1)
# ⏱️ Thời gian huấn luyện: 4544.51 giây
# ✅ Accuracy trung bình: 96.04%
# 🔗 Jaccard trung bình: 82.36%

# %%
# Trích xuất dữ liệu từ lịch sử huấn luyện
acc = history.history['accuracy']
loss = history.history['loss']
epochs_range = range(1, len(acc) + 1)

# Vẽ biểu đồ Accuracy và Loss
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Accuracy', color='green')
plt.title('Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Loss', color='red')
plt.title('Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

plt.tight_layout()

# Lưu hình ảnh vào file PNG
plt.savefig('begin_2750.png', dpi=300)

# Hiển thị biểu đồ
plt.show()

# %%
# Hàm hậu xử lý bằng Morphological Operations
def apply_morphology(mask, kernel_size=3, iterations=1):
    """
    Morphological post-processing: closing -> opening để loại bỏ nhiễu và lỗ hổng.
    - kernel_size: Kích thước kernel (thường 3, 5, 7).
    - iterations: Số lần áp dụng phép toán (1-2 là đủ).
    """
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (kernel_size, kernel_size))
    mask = (mask > 0.5).astype(np.uint8)  # Ngưỡng hóa trước

    # Closing để lấp lỗ hổng nhỏ
    closed = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel, iterations=iterations)

    # Opening để loại bỏ nhiễu
    opened = cv2.morphologyEx(closed, cv2.MORPH_OPEN, kernel, iterations=iterations)

    return opened.astype(np.float32)  # Chuyển về float để tính toán metrics

# Đánh giá mô hình gốc (không hậu xử lý)
print("🔍 Đánh giá không hậu xử lý...")
results = segunet.evaluate(test_images_gray_clahe, test_masks, verbose=1)
loss, accuracy, jaccard = results
print(f"Không hậu xử lý - Dice Loss: {loss:.4f}, Accuracy: {accuracy*100:.2f}%, Jaccard: {jaccard*100:.2f}%")

# Dự đoán và hậu xử lý chỉ với Morphological Operations
print("\n🔧 Đánh giá sau Morphology...")
predictions1 = segunet.predict(test_images_gray_clahe)
refined_predictions1 = []

for i in tqdm(range(len(test_images_gray_clahe))):
    pred = predictions1[i].squeeze()

    # Áp dụng Morphological Operations
    morph_pred = apply_morphology(pred, kernel_size=, iterations=2)

    refined_predictions1.append(morph_pred)

    # Lưu ảnh mẫu để so sánh
    # if i < 3:
    #     cv2.imwrite(f'before_morph_{i}.png', (pred > 0.5).astype(np.uint8) * 255)
    #     cv2.imwrite(f'after_morph_{i}.png', morph_pred * 255)

# Chuyển sang numpy array và thêm chiều channel nếu cần
refined_predictions1 = np.expand_dims(np.array(refined_predictions1), axis=-1)

# Tính toán metrics
accuracy_after = np_accuracy(test_masks, refined_predictions1)
jaccard_after = np_jaccard_coefficient(test_masks, refined_predictions1)
loss_after = np_dice_loss(test_masks, refined_predictions1)

print(f"Sau Morphology - Dice Loss: {loss_after:.4f}, Accuracy: {accuracy_after*100:.2f}%, Jaccard: {jaccard_after*100:.2f}%")
# Out:
# 🔍 Đánh giá không hậu xử lý...
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9501 - jaccard_coefficient: 0.7918 - loss: 0.1187
# E0000 00:00:1748819498.001614     179 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1748819498.240159     179 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1748819499.394355     179 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1748819499.658056     179 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1748819507.079688     179 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1748819507.318406     179 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 28s 990ms/step - accuracy: 0.9499 - jaccard_coefficient: 0.7877 - loss: 0.1214
# Không hậu xử lý - Dice Loss: 0.1559, Accuracy: 94.67%, Jaccard: 73.69%
#
# 🔧 Đánh giá sau Morphology...
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 12s 333ms/step
# 100%|██████████| 825/825 [00:00<00:00, 1663.48it/s]
# Sau Morphology - Dice Loss: 0.1372, Accuracy: 94.65%, Jaccard: 75.88%

# %%
def show_predictions_with_metrics_grid(refined_predictions1,
                                       images, masks,
                                       indices,
                                       save_path):

    num_images = len(indices)
    plt.figure(figsize=(8, 4 * num_images))  # 2 cột, num_images hàng

    for i, idx in enumerate(indices):
        image = images[idx]
        true_mask = masks[idx]
        pred_morph = refined_predictions1[idx]

        # Resize pred_morph về cùng kích thước với true_mask nếu cần
        if pred_morph.shape != true_mask.shape:
            pred_morph = cv2.resize(pred_morph, (true_mask.shape[1], true_mask.shape[0]), interpolation=cv2.INTER_NEAREST)

        # Tính metrics
        accuracy = np_accuracy(true_mask, pred_morph)

        # Cột 1: Ảnh gốc
        ax1 = plt.subplot(num_images, 2, 2*i + 1)
        ax1.imshow(image)
        # ax1.set_title(f"Ảnh gốc - idx {idx}", fontsize=14)
        ax1.axis('off')

        # Cột 2: Ảnh morphology + metrics
        ax2 = plt.subplot(num_images, 2, 2*i + 2)
        ax2.imshow(pred_morph, cmap='gray')
        # ax2.set_title("Hậu xử lý Morphology", fontsize=14)
        ax2.axis('off')
        ax2.text(0.5, -0.01,
                 f"Accuracy: {accuracy:.3f}",
                 fontsize=16, ha='center', va='top', transform=ax2.transAxes)

    plt.tight_layout()
    plt.savefig(save_path, bbox_inches='tight', dpi=300)
    plt.show()


show_predictions_with_metrics_grid(
    refined_predictions1=refined_predictions1,
    images=test_images,
    masks=test_masks,
    indices=[11, 44, 75, 123],  # 4 ảnh
    save_path="/kaggle/working/begin2750.png"
)
